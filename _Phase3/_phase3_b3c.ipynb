# %%
# Script source: GitHub repo
import os
import shutil

github_url_path = "https://github.com/abdoljh/Lamahat/tree/main/_Phase3"

# Extract the base GitHub repository URL and the subfolder path
def parse_github_path(url):
    parts = url.split('/tree/main/')
    repo_url = parts[0]
    subfolder_path = parts[1] if len(parts) > 1 else ''
    # Add .git for cloning
    repo_url_for_clone = repo_url + '.git'
    return repo_url_for_clone, subfolder_path

repo_url_for_clone, subfolder_path_in_repo = parse_github_path(github_url_path)

repo_name = repo_url_for_clone.split('/')[-1].replace('.git', '')
temp_clone_dir = os.path.join('/tmp', repo_name)
dest_dir_colab = '/content'

print(f"Cloning repository: {repo_url_for_clone}")
print(f"Target subfolder in repo: {subfolder_path_in_repo}")

# Clean up any previous clone to avoid issues
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Removed existing temporary directory: {temp_clone_dir}")

# Clone the repository
clone_command = f"git clone {repo_url_for_clone} {temp_clone_dir}"
print(f"Executing: {clone_command}")
os.system(clone_command)

# Check if cloning was successful
if not os.path.exists(temp_clone_dir):
    print(f"Error: Failed to clone repository {repo_url_for_clone}")
else:
    source_dir_to_copy = os.path.join(temp_clone_dir, subfolder_path_in_repo)
    if not os.path.exists(source_dir_to_copy):
        print(f"Error: Subfolder '{subfolder_path_in_repo}' not found in cloned repository at '{source_dir_to_copy}'")
    else:
        print(f"Source directory to copy: {source_dir_to_copy}")
        print(f"Copying contents of '{source_dir_to_copy}' directly into '{dest_dir_colab}'.")

        try:
            for item in os.listdir(source_dir_to_copy):
                source_item_path = os.path.join(source_dir_to_copy, item)
                dest_item_path = os.path.join(dest_dir_colab, item)

                # If item already exists in destination, remove it to avoid errors
                if os.path.exists(dest_item_path):
                    if os.path.isdir(dest_item_path):
                        shutil.rmtree(dest_item_path)
                        print(f"Removed existing directory '{dest_item_path}'.")
                    else:
                        os.remove(dest_item_path)
                        print(f"Removed existing file '{dest_item_path}'.")

                if os.path.isdir(source_item_path):
                    shutil.copytree(source_item_path, dest_item_path)
                else:
                    shutil.copy2(source_item_path, dest_item_path)
                print(f"Copied '{source_item_path}' to '{dest_item_path}'.")
            print(f"Successfully copied contents of '{source_dir_to_copy}' to '{dest_dir_colab}'.")

        except Exception as e:
            print(f"An error occurred during directory contents copy: {e}")

# Clean up the cloned repository
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Cleaned up temporary clone directory: {temp_clone_dir}")
# Out:
# Cloning repository: https://github.com/abdoljh/Lamahat.git
# Target subfolder in repo: _Phase3
# Executing: git clone https://github.com/abdoljh/Lamahat.git /tmp/Lamahat
# Source directory to copy: /tmp/Lamahat/_Phase3
# Copying contents of '/tmp/Lamahat/_Phase3' directly into '/content'.
# Copied '/tmp/Lamahat/_Phase3/Phase3.md' to '/content/Phase3.md'.
# Copied '/tmp/Lamahat/_Phase3/verify_font_discovery.py' to '/content/verify_font_discovery.py'.
# Copied '/tmp/Lamahat/_Phase3/samples' to '/content/samples'.
# Copied '/tmp/Lamahat/_Phase3/_phase3_b3a.ipynb' to '/content/_phase3_b3a.ipynb'.
# Copied '/tmp/Lamahat/_Phase3/artifacts' to '/content/artifacts'.
# Copied '/tmp/Lamahat/_Phase3/phase3' to '/content/phase3'.
# Copied '/tmp/Lamahat/_Phase3/prebuild_assets.py' to '/content/prebuild_assets.py'.
# Copied '/tmp/Lamahat/_Phase3/fonts' to '/content/fonts'.
# Copied '/tmp/Lamahat/_Phase3/audit_plan.py' to '/content/audit_plan.py'.
# Copied '/tmp/Lamahat/_Phase3/review' to '/content/review'.
# Copied '/tmp/Lamahat/_Phase3/INSTALL.md' to '/content/INSTALL.md'.
# Copied '/tmp/Lamahat/_Phase3/phase3_run.py' to '/content/phase3_run.py'.
# Copied '/tmp/Lamahat/_Phase3/output' to '/content/output'.
# Copied '/tmp/Lamahat/_Phase3/render_plan.py' to '/content/render_plan.py'.
# Successfully copied contents of '/tmp/Lamahat/_Phase3' to '/content'.
# Cleaned up temporary clone directory: /tmp/Lamahat

# %%
# Verify font discovery (OPTIONAL)
# !python verify_font_discovery.py

# %%
# Check font paths (OPTIONAL)
# !python -c "from phase3.typography import FONT_PATHS; print(FONT_PATHS)"
# print("✅ Pre-testingvthe discovery of Amiri fonts completed!")

# %%
# !pip install anthropic
print("✴️ Anthropic installed!")
# Out:
# Collecting anthropic
#   Downloading anthropic-0.102.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.102.0-py3-none-any.whl (763 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.1/763.1 kB 25.5 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.102.0
# ✴️ Anthropic installed!

# %%
# !pip install whisperx openai-whisper
# print("✅ whisperx and openai-whisper installed!")

# %%
# !pip install arabic-reshaper python-bidi
# print("✅ Arabic_reshaper and python-bidi installed!")

# %%
print("Retrieving the Anthropic & Pexels API keys ...")
from google.colab import userdata
import os

# Retrieve the Anthropic API key from Colab Secrets
anthropic_api_key = userdata.get('ANTHROPIC_API_KEY')
pexels_api_key = userdata.get('PEXELS_API_KEY')

# Set it as an environment variable for phase3_run.py to use
if anthropic_api_key:
    os.environ['ANTHROPIC_API_KEY'] = anthropic_api_key
    print("🔑 Anthropic API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: ANTHROPIC_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")

if pexels_api_key:
    os.environ['PEXELS_API_KEY'] = pexels_api_key
    print("🔑 Pexels API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: PEXELS_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")
# Out:
# Retrieving the Anthropic & Pexels API keys ...
# 🔑 Anthropic API key loaded from secrets and set as environment variable.
# 🔑 Pexels API key loaded from secrets and set as environment variable.

# %%
# Confirm alignment works (interpolation backend — no install needed)
# !python phase3_run.py \
    --script samples/al_askari_script.txt \
    --audio output/al_askari_audio.mp3 \
    --align-only \
    --align-backend interpolated

print("✅ Confirming alignment completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,045 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
# Backend: interpolated
#
# ── Running alignment ──────────────────────────────────────────────
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#
#   Aligned 653 words in 0.0 s
#   Backend used: interpolated
#
# ── First 30 word timings ──────────────────────────────────────────
#      0.00s →    1.18s   (1.18s)   مُذَكِّرات
#      1.18s →    1.65s   (0.47s)   جعفر
#      1.65s →    2.60s   (0.95s)   العسكريْ
#      2.60s →    2.95s   (0.35s)   رجل
#      2.95s →    3.43s   (0.47s)   واحد
#      3.43s →    3.78s   (0.35s)   حمل
#      3.78s →    4.49s   (0.71s)   سلاحاً
#      4.49s →    4.73s   (0.24s)   من
#      4.73s →    5.08s   (0.35s)   أجل
#      5.08s →    5.67s   (0.59s)   تحرير
#      5.67s →    6.26s   (0.59s)   وطنه،
#      6.26s →    6.74s   (0.47s)   لكنه
#      6.74s →    7.45s   (0.71s)   اكتشفَ
#      7.45s →    7.92s   (0.47s)   أنَّ
#      7.92s →    8.39s   (0.47s)   أشرس
#      8.39s →    9.22s   (0.83s)   الأعداء
#      9.22s →    9.46s   (0.24s)   قد
#      9.46s →   10.17s   (0.71s)   يكونون
#     10.17s →   10.40s   (0.24s)   من
#     10.40s →   10.87s   (0.47s)   داخل
#     10.87s →   11.47s   (0.59s)   صفوفك
#     11.47s →   11.82s   (0.35s)   هذه
#     11.82s →   12.29s   (0.47s)   ليست
#     12.29s →   12.88s   (0.59s)   رواية
#     12.88s →   13.36s   (0.47s)   خيال
#     13.36s →   14.18s   (0.83s)   تاريخي،
#     14.18s →   14.42s   (0.24s)   بل
#     14.42s →   15.13s   (0.71s)   شهادةٌ
#     15.13s →   15.72s   (0.59s)   حيّةٌ
#     15.72s →   15.96s   (0.24s)   من
#   … and 623 more
#
# Word timings → output/word_timings.json
# ✅ Confirming alignment completed!

# %%
# Step 1: plan as before — produces output/al_askari_plan_v2.json
# Regenerate the plan with the fixes
# !python phase3_run.py \
    --script  samples/al_askari_script.txt \
    --audio   output/al_askari_audio.mp3 \
    --book-title "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --plan-only \
    --save-plan output/al_askari_plan_v2.json

print("✅ Regenerating the plan completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,045 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
#
# ── Step 1: Forced alignment ───────────────────────────────────────
# WARNING  phase3.align  Backend whisperx failed: No module named 'whisperx'
# WARNING  phase3.align  Backend whisper failed: No module named 'whisper'
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#   653 words aligned via interpolated (0.0s)
#
# ── Step 2: AI shot planner ────────────────────────────────────────
# INFO  phase3.plan  Calling claude-sonnet-4-6 for shot plan (target=65 shots, 5.0s avg, 391.0s total)
# INFO  httpx  HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO  phase3.plan  Normalised 5 shot(s) with conflicting fields
# INFO  phase3.plan  Clipping shot 381.54-391.00s to 391.00s (audio end)
# INFO  phase3.plan  Merged 3 adjacent identical shot(s) — final plan 53 shots
# INFO  phase3.plan  Plan produced: 53 shots
#   53 shots planned in 91.7s
#
# Plan: 53 shots, 391.0s total
# ────────────────────────────────────────────────────────────────────────────────────────────
# Visuals: typography:20  broll:8  portrait:7  archive:7  section_mark:4  location:3  title_card:2  object:2
# ────────────────────────────────────────────────────────────────────────────────────────────
#     1. [  opening]   0.00-  3.78s ( 3.8s) title_card     static_hold
#     2. [  opening]   3.78- 10.17s ( 6.4s) typography     static_hold   "رجل واحد حمل سلاحاً من أجل تحرير وطنه"
#     3. [  opening]  10.17- 16.31s ( 6.1s) broll          slow_push     Ottoman Empire soldiers marching 1910 historical
#     4. [  opening]  16.31- 22.46s ( 6.1s) typography     static_hold   "شهادةٌ حيّةٌ من قلب أحداثٍ غيّرت وجهَ المنطقة العر"
#     5. [  opening]  22.46- 29.43s ( 7.0s) portrait       static_hold   Jafar al-Askari Iraqi officer historical portrait
#     6. [  opening]  29.43- 36.76s ( 7.3s) archive        slow_push     Ottoman Empire fall Arab Revolt historical archive 1916
#     7. [  opening]  36.76- 43.02s ( 6.3s) typography     static_hold   "كيف يصنع العسكري ثورة؟"
#     8. [  opening]  43.02- 51.30s ( 8.3s) broll          slow_push     Arab soldiers desert loyalty homeland 1910s
#     9. [  opening]  51.30- 55.79s ( 4.5s) section_mark   static_hold
#    10. [  opening]  55.79- 62.29s ( 6.5s) location       pan_right     Mosul Iraq historical photograph 1900s Ottoman era
#    11. [  opening]  62.29- 68.79s ( 6.5s) location       slow_push     Istanbul Constantinople Ottoman military academy 1900s
#    12. [  opening]  68.79- 75.53s ( 6.7s) typography     static_hold   "عبوراً من عالم تقليدي إلى آفاق حديثة مليئة بالمناه"
#    13. [  opening]  75.53- 82.15s ( 6.6s) archive        slow_push     Ottoman military academy cadets classroom Istanbul 1905
#    14. [  opening]  82.15- 89.95s ( 7.8s) portrait       static_hold   Jafar al-Askari young officer uniform Ottoman
#    15. [  opening]  89.95- 96.92s ( 7.0s) typography     static_hold   "جميعهم يحملون حلماً واحداً إصلاح الجيش والدولة"
#    16. [  opening]  96.92-105.20s ( 8.3s) portrait       static_hold   Mahmud Shawkat Pasha Ottoman general portrait
#    17. [  opening] 105.20-113.71s ( 8.5s) archive        slow_push     Ottoman army modernization reform 1908 historical photo
#    18. [  opening] 113.71-122.69s ( 9.0s) typography     static_hold   "الإصلاح الحقيقي لا يتوقف على التسليح والتَّكْتِيكا"
#    19. [  opening] 122.69-130.02s ( 7.3s) broll          slow_push     Ottoman officers reading books discussion intellectual 1900s
#    20. [  opening] 130.02-138.17s ( 8.2s) typography     static_hold   "طموح جيل كامل آمن أن التعليم والجيش الحديث يمكنهما"
#    21. [  opening] 138.17-146.57s ( 8.4s) section_mark   static_hold
#    22. [  opening] 146.57-154.37s ( 7.8s) broll          slow_push     Committee of Union Progress Ottoman secret meeting 1908
#    23. [  opening] 154.37-162.40s ( 8.0s) archive        slow_push     Young Turks revolution 1908 Ottoman Istanbul street crowd
#    24. [  opening] 162.40-170.21s ( 7.8s) typography     static_hold   "انقلاب ١٩٠٨ الشهير، الذي أطاح بالسلطان عبدالحميد ا"
#    25. [  opening] 170.21-178.24s ( 8.0s) portrait       static_hold   Sultan Abdulhamid II Ottoman portrait deposed 1909
#    26. [  opening] 178.24-186.75s ( 8.5s) typography     static_hold   "رأى بعينيه كيف يمكن لقوة عسكرية منظمة أن تغيّر مسا"
#    27. [  opening] 186.75-195.97s ( 9.2s) broll          slow_push     Ottoman political corruption intrigue 1910s historical
#    28. [  opening] 195.97-204.48s ( 8.5s) typography     static_hold   "النظام الجديد حمل فساداً من نوع آخر، ومصالح شخصية "
#    29. [  opening] 204.48-213.58s ( 9.1s) portrait       static_hold   Jafar al-Askari officer uniform Iraq Arab Revolt
#    30. [  opening] 213.58-222.57s ( 9.0s) typography     static_hold   "صراع الضميرين ضمير الجندي الوفي لدولته وضمير الوطن"
#    31. [  opening] 222.57-230.61s ( 8.0s) section_mark   static_hold
#    32. [  opening] 230.61-237.11s ( 6.5s) archive        fast_push     Balkan Wars 1912 Ottoman army retreat historical photo
#    33. [  opening] 237.11-244.08s ( 7.0s) typography     static_hold   "لم يَعُدْ هناك متسعٌ للنظرياتِ والأحلامْ"
#    34. [  opening] 244.08-251.41s ( 7.3s) broll          slow_push     World War One Middle East Ottoman desert soldiers 1916
#    35. [  opening] 251.41-258.97s ( 7.6s) typography     static_hold   "هل يبقى جندياً وفياً للدولةِ العثمانيةِ المتداعية،"
#    36. [  opening] 258.97-265.59s ( 6.6s) location       pan_right     North Africa Libya desert Senussi movement 1915 historical
#    37. [  opening] 265.59-273.28s ( 7.7s) archive        slow_push     Senussi movement Libya Arab fighters World War One
#    38. [  opening] 273.28-281.90s ( 8.6s) typography     static_hold   "المذكرات تروي بتفاصيل دقيقة كيفية إدارة هذه العملي"
#    39. [  opening] 281.90-290.06s ( 8.2s) archive        slow_push     Arab Revolt Hejaz 1916 Faisal Hussein sharif desert campaign
#    40. [  opening] 290.06-293.96s ( 3.9s) typography     static_hold   "تاريخ الشرق الأوسط الحديث مكتوب جزئياً من خلال قرا"
#    41. [  closing] 293.96-298.21s ( 4.3s) section_mark   static_hold
#    42. [  closing] 298.21-305.19s ( 7.0s) object         slow_push     old Arabic memoir book cover aged pages historical
#    43. [  closing] 305.19-313.34s ( 8.2s) typography     static_hold   "دعوة للتأمل العميق حول طبيعة الولاء والوطنية، وحول"
#    44. [  closing] 313.34-320.91s ( 7.6s) broll          slow_push     Arab men reading contemplating historical crossroads 1920s
#    45. [  closing] 320.91-328.36s ( 7.4s) portrait       static_hold   Najda Fathi Safwa Arab historian scholar portrait
#    46. [  closing] 328.36-336.16s ( 7.8s) typography     static_hold   "فرصة نادرة للدخول إلى عقل ضابط عاش أهم لحظات التار"
#    47. [  closing] 336.16-343.37s ( 7.2s) object         slow_push     historical Arabic manuscripts documents letters maps archive
#    48. [  closing] 343.37-350.70s ( 7.3s) typography     static_hold   "بين دفتي هذا الكتاب ستجد نقاشاً صريحاً عن الفساد و"
#    49. [  closing] 350.70-358.14s ( 7.4s) broll          slow_pull     Iraqi Arab officer World War One desert camp contemplative
#    50. [  closing] 358.14-366.77s ( 8.6s) typography     static_hold   "برجل حقيقي، لا بطلٍ أسطوري، بل برجل تَرَدَّدَ وتأل"
#    51. [  closing] 366.77-375.75s ( 9.0s) typography     static_hold   "فهم حاضرنا لا يتحقق إلا بفهم عميق لماضينا الذي عاش"
#    52. [  closing] 375.75-381.54s ( 5.8s) portrait       static_hold   Jafar al-Askari Iraqi statesman Baghdad 1921 historical
#    53. [  closing] 381.54-391.00s ( 9.5s) title_card     static_hold
#
# Shot plan → output/al_askari_plan_v2.json
# Word timings → output/word_timings.json
# ✅ Regenerating the plan completed!

# %%
# Audit it
# !python audit_plan.py output/al_askari_plan_v2.json
# Expect: ~43 shots, <10% auto-split

print("✅ Audit completed!")
# Out:
# ======================================================================
# PLAN AUDIT
# ======================================================================
#
# Total shots:        53
# Plan timeline:      0.00s → 391.00s (391.0s)
# Average shot:       7.38s
# Range:              3.78s – 9.46s
#
# ✓  No gaps or overlaps
#
# Visual types:
#    typography      20 (  38%) ███████████
#    broll            8 (  15%) ████
#    portrait         7 (  13%) ███
#    archive          7 (  13%) ███
#    section_mark     4 (   8%) ██
#    location         3 (   6%) █
#    title_card       2 (   4%) █
#    object           2 (   4%) █
#
# Motion types:
#    static_hold     33 (  62%) ██████████████████
#    slow_push       16 (  30%) █████████
#    pan_right        2 (   4%) █
#    fast_push        1 (   2%)
#    slow_pull        1 (   2%)
#
# Section coverage:
#    opening         40 shots
#    closing         13 shots
#
# ✓  Auto-split shots: 3/53 (6%) from 3 original(s)
#      Implied original Sonnet shot count: 53
#
# Typography texts: 26 unique (26 occurrences after splits)
#    Word count: min=3, max=18, avg=10.3
#    Templates: chapter_heading:6, pull_quote:19, date_stamp:1
#
#
# Search queries: 27 non-empty, avg 7.2 words
#    ✓ Bare (1–2 words): 0 (none — good specificity)
#
# ======================================================================
# ✅ Audit completed!

# %%
import os

# Step 2 (NEW): prebuild — run every source, score every candidate,
# write a review dossier.  No video render.
# !python prebuild_assets.py \
    --plan          output/al_askari_plan_v2.json \
    --script        samples/al_askari_script.txt \
    --book-title    "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --anthropic-key "$ANTHROPIC_API_KEY" \
    --pexels-key    "$PEXELS_API_KEY" \
    --review-dir    output/review/ \
    --character-portrait my_jafar.jpg
# Out:
# INFO    phase3.prebuild  Loaded plan: 53 shots
# INFO    phase3.prebuild  Image-needing shots: 27 (the rest are typography)
# INFO    phase3.prebuild  Pinned portrait copied → /content/output/review2/overrides/character.jpg
# INFO    phase3.prebuild  Shot 3/broll: query='Ottoman Empire soldiers marching 1910 historical' duration=6.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire soldiers marching 1910 historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire soldiers marching 1910 historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire soldiers marching 1910 historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire soldiers marching 1910 historical'
# WARNING phase3.sources.vision  Vision: error on A formal military parade with soldiers i: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kdh9GPQ5BwtkkKiDB2'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A group of men in traditional 18th-centu: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kdivvJig8ivvE7aiW6'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Turkish soldiers in uniform marching at : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kdkZtfZM8w5JbBo8sA'} — keeping with neutral score
# INFO    phase3.sources  Shot 3: best=A formal military parade with soldiers in uniform  (score 5)
# INFO    phase3.prebuild  Shot 5/portrait: query='Jafar al-Askari Iraqi officer historical portrait' duration=7.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi officer historical portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi officer historical portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi officer historical portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi officer historical portrait'
# WARNING phase3.sources.vision  Vision: error on Man in a tuxedo smiling indoors in a lux: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8ke68sVHKtxvk2uhDWX'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Portrait of a man in a historical milita: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8ke7cBQBYMsvTEwgmxu'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A man in period military costume poses i: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8ke9FQDQrbDaWcHFLbB'} — keeping with neutral score
# INFO    phase3.sources  Shot 5: best=Man in a tuxedo smiling indoors in a luxurious, or (score 5)
# INFO    phase3.prebuild  Shot 6/archive: query='Ottoman Empire fall Arab Revolt historical archive 1916' duration=7.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire fall Arab Revolt historical archive 1916'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire fall Arab Revolt historical archive 1916'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire fall Arab Revolt historical archive 1916'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire fall Arab Revolt historical archive 1916'
# WARNING phase3.sources.vision  Vision: error on Beautiful Islamic calligraphy decorates : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8keZgaH5NFux3HgPFtk'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Stunning architectural view of Hagia Sop: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kebNHDQ4jz4XpKRjdL'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Ornate gate of Dolmabahçe Palace, Istanb: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kecsZYmvgbUbTJ8sjW'} — keeping with neutral score
# INFO    phase3.sources  Shot 6: best=Beautiful Islamic calligraphy decorates the interi (score 5)
# INFO    phase3.prebuild  Shot 8/broll: query='Arab soldiers desert loyalty homeland 1910s' duration=8.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab soldiers desert loyalty homeland 1910s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab soldiers desert loyalty homeland 1910s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab soldiers desert loyalty homeland 1910s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab soldiers desert loyalty homeland 1910s'
# WARNING phase3.sources.vision  Vision: error on Libyan soldiers holding rifles and red f: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kf5UDKaDUUsVs665Lw'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Silhouette of a camel with two people wa: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kf6t3vNV2HL7QDcFJr'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Horsemen in traditional attire ride eleg: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kf8NbGPSW2dtXxzJTv'} — keeping with neutral score
# INFO    phase3.sources  Shot 8: best=Libyan soldiers holding rifles and red flares in a (score 5)
# INFO    phase3.prebuild  Shot 10/location: query='Mosul Iraq historical photograph 1900s Ottoman era' duration=6.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mosul Iraq historical photograph 1900s Ottoman era'
# WARNING phase3.sources.vision  Vision: error on Explore an ancient Ottoman cemetery with: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kfYtELVXCBjSWW4NrM'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Explore the historic ruins of ancient Ba: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kfaKJZiWnY7yDGQciE'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A striking black and white aerial view s: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kfbpbA339QQB3icuxp'} — keeping with neutral score
# INFO    phase3.sources  Shot 10: best=Explore an ancient Ottoman cemetery with intricate (score 5)
# INFO    phase3.prebuild  Shot 11/location: query='Istanbul Constantinople Ottoman military academy 1900s' duration=6.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Istanbul Constantinople Ottoman military academy 1900s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Istanbul Constantinople Ottoman military academy 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Istanbul Constantinople Ottoman military academy 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Istanbul Constantinople Ottoman military academy 1900s'
# WARNING phase3.sources.vision  Vision: error on Fener Greek High School building in Bala: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kfs38qbVZK4QQK89RQ'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Historic Kuleli Military School on the B: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kfte8KyzG68BfSsde8'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Stunning view of the iconic Sultan Ahmed: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kfvHqxbBmLoSh9DE1m'} — keeping with neutral score
# INFO    phase3.sources  Shot 11: best=Fener Greek High School building in Balat, Istanbu (score 5)
# INFO    phase3.prebuild  Shot 13/archive: query='Ottoman military academy cadets classroom Istanbul 1905' duration=6.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman military academy cadets classroom Istanbul 1905'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman military academy cadets classroom Istanbul 1905'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman military academy cadets classroom Istanbul 1905'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman military academy cadets classroom Istanbul 1905'
# WARNING phase3.sources.vision  Vision: error on A military officer oversees a formation : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kgTCx414ZXy2WZBsjp'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Explore the ornate Ottoman library with : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kgUwdHXET6RAduhxgD'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Close-up of bronze Ottoman soldier statu: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kgWpV8p7nQpJXNatpf'} — keeping with neutral score
# INFO    phase3.sources  Shot 13: best=A military officer oversees a formation during a v (score 5)
# INFO    phase3.prebuild  Shot 14/portrait: query='Jafar al-Askari young officer uniform Ottoman' duration=7.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari young officer uniform Ottoman'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari young officer uniform Ottoman'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari young officer uniform Ottoman'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari young officer uniform Ottoman'
# WARNING phase3.sources.vision  Vision: error on Man in a detailed historical officer uni: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kgtRznijQWB7SsUk8r'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A group of uniformed officers gathered o: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kguraM5gi2QSjBGxmk'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Group of navy officers in white uniforms: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kgwFueDSHDeFYeJRXw'} — keeping with neutral score
# INFO    phase3.sources  Shot 14: best=Man in a detailed historical officer uniform stand (score 5)
# INFO    phase3.prebuild  Shot 16/portrait: query='Mahmud Shawkat Pasha Ottoman general portrait' duration=8.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mahmud Shawkat Pasha Ottoman general portrait'
# WARNING phase3.sources.vision  Vision: error on Intricate frescoes and architecture of K: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8khBySZm9MqEZHMK99U'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Explore the intricate architecture and d: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8khE8B7au9qihiw5rkS'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on View of the detailed dome and Arabic cal: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8khFdDJi6Nhx3WgGAYZ'} — keeping with neutral score
# INFO    phase3.sources  Shot 16: best=Intricate frescoes and architecture of Kılıç Ali P (score 5)
# INFO    phase3.prebuild  Shot 17/archive: query='Ottoman army modernization reform 1908 historical photo' duration=8.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman army modernization reform 1908 historical photo'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman army modernization reform 1908 historical photo'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman army modernization reform 1908 historical photo'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman army modernization reform 1908 historical photo'
# WARNING phase3.sources.vision  Vision: error on Polish soldiers on horseback holding fla: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8khbyKgWuJ9yK95Kk25'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Close-up of bronze Ottoman soldier statu: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8khdRdxNLHqDaEH11dS'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A beautiful historic building in Edirne,: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8khf1tKPYocMFw6aLF3'} — keeping with neutral score
# INFO    phase3.sources  Shot 17: best=Polish soldiers on horseback holding flags, showca (score 5)
# INFO    phase3.prebuild  Shot 19/broll: query='Ottoman officers reading books discussion intellectual 1900s' duration=7.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman officers reading books discussion intellectual 1900s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman officers reading books discussion intellectual 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman officers reading books discussion intellectual 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman officers reading books discussion intellectual 1900s'
# WARNING phase3.sources.vision  Vision: error on Warm-toned library interior featuring op: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kiLTCa6pJztuJxCL6Y'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A diverse group of young adults studying: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kiND7pCRtKC3QkymNs'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Two people working in a cozy setting wit: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kiPmt686Grixc4Buap'} — keeping with neutral score
# INFO    phase3.sources  Shot 19: best=Warm-toned library interior featuring open books o (score 5)
# INFO    phase3.prebuild  Shot 22/broll: query='Committee of Union Progress Ottoman secret meeting 1908' duration=7.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Committee of Union Progress Ottoman secret meeting 1908'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Committee of Union Progress Ottoman secret meeting 1908'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Committee of Union Progress Ottoman secret meeting 1908'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Committee of Union Progress Ottoman secret meeting 1908'
# WARNING phase3.sources.vision  Vision: error on Historic Legacy Ottoman Hotel in Istanbu: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kimWq296vbALHr3tGU'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Captivating view of historic domes overl: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kio18ZsoE1nwun8zfa'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Ornate 19th-century Ottoman architecture: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kipVv59R3Nu3BdiXAc'} — keeping with neutral score
# INFO    phase3.sources  Shot 22: best=Historic Legacy Ottoman Hotel in Istanbul showcasi (score 5)
# INFO    phase3.prebuild  Shot 23/archive: query='Young Turks revolution 1908 Ottoman Istanbul street crowd' duration=8.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Young Turks revolution 1908 Ottoman Istanbul street crowd'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Young Turks revolution 1908 Ottoman Istanbul street crowd'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Young Turks revolution 1908 Ottoman Istanbul street crowd'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Young Turks revolution 1908 Ottoman Istanbul street crowd'
# WARNING phase3.sources.vision  Vision: error on A bustling crowd gathers outside a histo: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kjKWBJftfTMhFYMiFg'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A serene street in Heybeliada, featuring: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kjNN5MmmAQq1vSzouR'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A bustling crowd gathers near the iconic: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kjPuMDppdyMMFSko7L'} — keeping with neutral score
# INFO    phase3.sources  Shot 23: best=A bustling crowd gathers outside a historic mosque (score 5)
# INFO    phase3.prebuild  Shot 25/portrait: query='Sultan Abdulhamid II Ottoman portrait deposed 1909' duration=8.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Sultan Abdulhamid II Ottoman portrait deposed 1909'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Sultan Abdulhamid II Ottoman portrait deposed 1909'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Sultan Abdulhamid II Ottoman portrait deposed 1909'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Sultan Abdulhamid II Ottoman portrait deposed 1909'
# WARNING phase3.sources.vision  Vision: error on Close-up of bronze Ottoman soldier statu: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kjvjzanYDgazJUp7vB'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A beautifully adorned Ottoman fountain i: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kjxKz7V38SEiyaZE7k'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Intricate architecture and Islamic art i: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kjyxTzP7j8138jETqj'} — keeping with neutral score
# INFO    phase3.sources  Shot 25: best=Close-up of bronze Ottoman soldier statues in Ista (score 5)
# INFO    phase3.prebuild  Shot 27/broll: query='Ottoman political corruption intrigue 1910s historical' duration=9.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman political corruption intrigue 1910s historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman political corruption intrigue 1910s historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman political corruption intrigue 1910s historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman political corruption intrigue 1910s historical'
# WARNING phase3.sources.vision  Vision: error on Majestic statue of Atatürk on horseback : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kkMR43jPhhcHvvdB8N'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Ottoman architecture of Legacy Ottoman H: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kkP5mSmjojESQaQLvD'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Entrance of the historic Kurşunlu Han in: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kkQZKDkzcti38Fkktx'} — keeping with neutral score
# INFO    phase3.sources  Shot 27: best=Majestic statue of Atatürk on horseback in İzmir,  (score 5)
# INFO    phase3.prebuild  Shot 29/portrait: query='Jafar al-Askari officer uniform Iraq Arab Revolt' duration=9.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari officer uniform Iraq Arab Revolt'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari officer uniform Iraq Arab Revolt'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari officer uniform Iraq Arab Revolt'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari officer uniform Iraq Arab Revolt'
# WARNING phase3.sources.vision  Vision: error on A man in traditional Yemeni dress poses : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kki71Cekgf69WMBjGk'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Group of navy officers in white uniforms: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kkjVM9notJqtuVcCTo'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Man in a detailed historical officer uni: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kkkwuMprF1qsMaLzFh'} — keeping with neutral score
# INFO    phase3.sources  Shot 29: best=A man in traditional Yemeni dress poses with a rif (score 5)
# INFO    phase3.prebuild  Shot 32/archive: query='Balkan Wars 1912 Ottoman army retreat historical photo' duration=6.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Balkan Wars 1912 Ottoman army retreat historical photo'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Balkan Wars 1912 Ottoman army retreat historical photo'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Balkan Wars 1912 Ottoman army retreat historical photo'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Balkan Wars 1912 Ottoman army retreat historical photo'
# WARNING phase3.sources.vision  Vision: error on Bronze relief depicting soldiers at a me: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8km4Jge4kpK7xW13RYW'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Bronze statue and relief honoring Turkis: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8km5qDU1LdREomdSzCM'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Discover the historical Konjic Bridge, a: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8km7WfXrBAh6PM81dLk'} — keeping with neutral score
# INFO    phase3.sources  Shot 32: best=Bronze relief depicting soldiers at a memorial sit (score 5)
# INFO    phase3.prebuild  Shot 34/broll: query='World War One Middle East Ottoman desert soldiers 1916' duration=7.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'World War One Middle East Ottoman desert soldiers 1916'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'World War One Middle East Ottoman desert soldiers 1916'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'World War One Middle East Ottoman desert soldiers 1916'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'World War One Middle East Ottoman desert soldiers 1916'
# WARNING phase3.sources.vision  Vision: error on Libyan soldiers holding rifles and red f: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kmUjs2dTQ3Rdkay2vf'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A soldier in uniform holding a rifle aga: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kmW8D49ecvTWWGBF8J'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Two riders in military attire on horseba: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kmXVZ6TK1mio72z2cR'} — keeping with neutral score
# INFO    phase3.sources  Shot 34: best=Libyan soldiers holding rifles and red flares in a (score 5)
# INFO    phase3.prebuild  Shot 36/location: query='North Africa Libya desert Senussi movement 1915 historical' duration=6.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'North Africa Libya desert Senussi movement 1915 historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'North Africa Libya desert Senussi movement 1915 historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'North Africa Libya desert Senussi movement 1915 historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'North Africa Libya desert Senussi movement 1915 historical'
# WARNING phase3.sources.vision  Vision: error on Old ruins in Matrouh, Egypt with a lush : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kmvBodGfoPRZN7ufFN'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Footprints trail across sand dunes in Mo: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kmwecdywfnMXpmnqZT'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A solitary figure crosses the golden san: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kmy2xg7QtNVgCw3k6Q'} — keeping with neutral score
# INFO    phase3.sources  Shot 36: best=Old ruins in Matrouh, Egypt with a lush oasis land (score 5)
# INFO    phase3.prebuild  Shot 37/archive: query='Senussi movement Libya Arab fighters World War One' duration=7.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Senussi movement Libya Arab fighters World War One'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Senussi movement Libya Arab fighters World War One'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Senussi movement Libya Arab fighters World War One'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Senussi movement Libya Arab fighters World War One'
# WARNING phase3.sources.vision  Vision: error on Libyan soldiers holding rifles and red f: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8knHMXv7GaieSzH8ZZ1'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A soldier signals with a red flare, surr: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8knJkcqobXr42NWB6yd'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A striking bronze statue of a World War : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8knLDRg47gpspD9WMKC'} — keeping with neutral score
# INFO    phase3.sources  Shot 37: best=Libyan soldiers holding rifles and red flares in a (score 5)
# INFO    phase3.prebuild  Shot 39/archive: query='Arab Revolt Hejaz 1916 Faisal Hussein sharif desert campaign' duration=8.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab Revolt Hejaz 1916 Faisal Hussein sharif desert campaign'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab Revolt Hejaz 1916 Faisal Hussein sharif desert campaign'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab Revolt Hejaz 1916 Faisal Hussein sharif desert campaign'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab Revolt Hejaz 1916 Faisal Hussein sharif desert campaign'
# WARNING phase3.sources.vision  Vision: error on Dramatic sunset over Saddam Hussein's Pa: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8knhRPLLguUQeahARWJ'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A herd of camels grazing in the vast des: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8knjF21rJdS7vz8ZAcL'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Silhouette of a camel with two people wa: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8knkwiCx8PeaGJ5p3Lw'} — keeping with neutral score
# INFO    phase3.sources  Shot 39: best=Dramatic sunset over Saddam Hussein's Palace in Ba (score 5)
# INFO    phase3.prebuild  Shot 42/object: query='old Arabic memoir book cover aged pages historical' duration=7.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'old Arabic memoir book cover aged pages historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'old Arabic memoir book cover aged pages historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'old Arabic memoir book cover aged pages historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'old Arabic memoir book cover aged pages historical'
# WARNING phase3.sources.vision  Vision: error on Detailed view of an ancient illuminated : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8ko4uhsdqGZ1S6Vzpa2'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A collection of vintage books and pages : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8ko6PFuZg19AouuiFSV'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A visually captivating still life featur: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8ko86CHCC5PdPHyQQn7'} — keeping with neutral score
# INFO    phase3.sources  Shot 42: best=Detailed view of an ancient illuminated manuscript (score 5)
# INFO    phase3.prebuild  Shot 44/broll: query='Arab men reading contemplating historical crossroads 1920s' duration=7.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab men reading contemplating historical crossroads 1920s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab men reading contemplating historical crossroads 1920s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab men reading contemplating historical crossroads 1920s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab men reading contemplating historical crossroads 1920s'
# WARNING phase3.sources.vision  Vision: error on Stunning view of a historic library's in: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8koVgUQ2qkwhDfT5KQS'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Middle Eastern man reading Quran in Kuwa: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8koX9HLkLg5d8gXSDFw'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on A man dressed in traditional clothing pr: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8koYpjRu5nayA3RLNTD'} — keeping with neutral score
# INFO    phase3.sources  Shot 44: best=Stunning view of a historic library's interior arc (score 5)
# INFO    phase3.prebuild  Shot 45/portrait: query='Najda Fathi Safwa Arab historian scholar portrait' duration=7.4s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Najda Fathi Safwa Arab historian scholar portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Najda Fathi Safwa Arab historian scholar portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Najda Fathi Safwa Arab historian scholar portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Najda Fathi Safwa Arab historian scholar portrait'
# WARNING phase3.sources.vision  Vision: error on A woman in a hijab observes paintings in: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kosm1g9czDsJKDsc1y'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Elegant portrait of a woman in a red dre: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kouTTYKcNe3TEjuoaG'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Artistic portrait of a woman in red atti: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kovvm6kmweNsK4gLt2'} — keeping with neutral score
# INFO    phase3.sources  Shot 45: best=A woman in a hijab observes paintings in a red-wal (score 5)
# INFO    phase3.prebuild  Shot 47/object: query='historical Arabic manuscripts documents letters maps archive' duration=7.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'historical Arabic manuscripts documents letters maps archive'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'historical Arabic manuscripts documents letters maps archive'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'historical Arabic manuscripts documents letters maps archive'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'historical Arabic manuscripts documents letters maps archive'
# WARNING phase3.sources.vision  Vision: error on Close-up of an ancient manuscript featur: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kpUFRnvJB6Sp9fkZiv'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Detailed view of an ancient illuminated : Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kpW4KfAWuj3LeSNrWf'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Detailed image of ancient Arabic calligr: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kpXwRySem1tRUGCr4h'} — keeping with neutral score
# INFO    phase3.sources  Shot 47: best=Close-up of an ancient manuscript featuring elabor (score 5)
# INFO    phase3.prebuild  Shot 49/broll: query='Iraqi Arab officer World War One desert camp contemplative' duration=7.4s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Iraqi Arab officer World War One desert camp contemplative'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Iraqi Arab officer World War One desert camp contemplative'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Iraqi Arab officer World War One desert camp contemplative'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Iraqi Arab officer World War One desert camp contemplative'
# WARNING phase3.sources.vision  Vision: error on A child stands in a muddy refugee camp i: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kpu2wadFHjyjowZnhs'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Explore the iconic desert landscape of t: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kpvVVjRrHNouaVv6sG'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Silhouette of a man in traditional attir: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kpwsM8PG8uP2xsMEzq'} — keeping with neutral score
# INFO    phase3.sources  Shot 49: best=A child stands in a muddy refugee camp in Syria, a (score 5)
# INFO    phase3.prebuild  Shot 52/portrait: query='Jafar al-Askari Iraqi statesman Baghdad 1921 historical' duration=5.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi statesman Baghdad 1921 historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi statesman Baghdad 1921 historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi statesman Baghdad 1921 historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi statesman Baghdad 1921 historical'
# WARNING phase3.sources.vision  Vision: error on Stunning view of traditional architectur: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kqCRCf9aSsgkLPduq3'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Vandalized sculpture in a Baghdad park u: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kqDwVAoFBASJuYfdy1'} — keeping with neutral score
# WARNING phase3.sources.vision  Vision: error on Man in a tuxedo smiling indoors in a lux: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'You have reached your specified API usage limits. You will regain access on 2026-06-01 at 00:00 UTC.'}, 'request_id': 'req_011Cb8kqFGMTDD7BLUwkcXWi'} — keeping with neutral score
# INFO    phase3.sources  Shot 52: best=Stunning view of traditional architecture in Baghd (score 5)
# INFO    phase3.sources.decisions  Decisions written → /content/output/review2/decisions.json
#
# ────────────────────────────────────────────────────────────────
# Review dossier ready: /content/output/review2
# Image shots processed:  27
#   with a chosen winner: 27
#   with no candidates:   0
# Winner source breakdown:
#   pexels           27
# Pinned portrait:        overrides/character.jpg
#   affects 7 portrait shot(s) at render time
#
# Next:
#   1. Open /content/output/review2/ and review each shot folder.
#   2. Edit /content/output/review2/decisions.json to swap candidates,
#      drop overrides into /content/output/review2/overrides/,
#      or set 'pinned_portrait'.
#   3. Render:
#      python render_plan.py --plan output/al_askari_plan_v2.json \
#          --review-dir /content/output/review2 \
#          --audio <audio> --output <output.mp4>
# ────────────────────────────────────────────────────────────────

# %%
import os
import zipfile

output_dir = 'output/review'
zip_filename = 'review.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    files_added = []
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            file_path = os.path.join(root, file)
            # Add file to zip, preserving directory structure relative to 'output_dir'
            # Skip .mp3 files if any exist (though unlikely in review folder)
            if not file_path.endswith('.mp3'):
                zipf.write(file_path, os.path.relpath(file_path, output_dir))
                files_added.append(file_path)

print(f"🤐 Successfully created '{zip_filename}' containing: ")
if files_added:
    for f in files_added:
        print(f"  - {f}")
else:
    print("  (No files found to zip in the 'output/review' directory.)")

# %%
# Step 3: user reviews output/review/ — opens decisions.json, swaps a
# few `chosen_url` values, drops shot_03.jpg / shot_38.jpg overrides.

# Step 4: render — render_plan.py reads the decisions file
# The --review-dir argument consumes user's choices
# !python render_plan.py \
    --plan         output/al_askari_plan_v2.json \
    --audio        output/al_askari_audio.mp3 \
    --review-dir   output/review/ \
    --output       output/final_cut.mp4 \
    > output/render.log 2>&1 &

# %%
# Monitor rendering progress
import time
from IPython.display import clear_output

log_path = "output/render.log"

print("Monitoring rendering progress...")
while True:
    try:
        # Read the log file contents
        try:
            with open(log_path, "r") as f:
                log_content = f.read()
        except FileNotFoundError:
            log_content = ""

        # Clear cell output and show the last 20 lines
        clear_output(wait=True)
        lines = log_content.splitlines()
        print("\n".join(lines[-20:]))

        # Check if the script's success signature is in the log
        if "Done in" in log_content or "Rendered video →" in log_content:
            print("\n✅ Rendering process completed successfully! Stopped monitoring.")
            break

        time.sleep(5)

    except KeyboardInterrupt:
        print("\n⚠️ Monitoring stopped manually. The script may still be running.")
        break
# Out:
#   [█████████████████████░░░░░░░░░]  71%  shot 50/53: typography                                                INFO  phase3.render  [render 72%] shot 51/53: typography
#
#   [█████████████████████░░░░░░░░░]  72%  shot 51/53: typography                                                INFO  phase3.sources  Shot 52: review-dossier hit character.jpg
# INFO  phase3.render  Shot 52: using fetched image from user_upload
# INFO  phase3.render  [render 74%] shot 52/53: portrait
#
#   [██████████████████████░░░░░░░░]  73%  shot 52/53: portrait                                                  INFO  phase3.render  [render 75%] shot 53/53: title_card
#
#   [██████████████████████░░░░░░░░]  74%  shot 53/53: title_card                                                INFO  phase3.render  [render 80%] concat all shots
#
#   [████████████████████████░░░░░░]  80%  concat all shots                                                      INFO  phase3.render  [render 86%] generating captions
#
#   [█████████████████████████░░░░░]  86%  generating captions                                                   INFO  phase3.render  [render 92%] mux audio and captions
#
#   [███████████████████████████░░░]  92%  mux audio and captions                                                INFO  phase3.render  [render 100%] done
#
#   [██████████████████████████████] 100%  done
# INFO  phase3.render  Rendered video → output/final_cut.mp4
#
# Done in 984s  —  output/final_cut.mp4  (26.8 MB)
#
# ✅ Rendering process completed successfully! Stopped monitoring.

# %%
# Zip output files for exporting
import os
import zipfile

output_dir = 'output'
zip_filename = 'output_files.zip'

# Get all files in the output directory
files_to_zip = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))]

# Filter out the .mp3 file
filtered_files = [f for f in files_to_zip if not f.endswith('.mp3')]

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file_path in filtered_files:
        # Add file to zip, preserving directory structure relative to 'output_dir'
        zipf.write(file_path, os.path.relpath(file_path, output_dir))

print(f"🤐 Successfully created '{zip_filename}' containing: ")
for f in filtered_files:
    print(f"  - {f}")

# %%
# Save zipped file to Drive
from google.colab import drive
drive.mount('/content/drive')

import shutil
import os

# Define the destination directory and file path
dest_dir = '/content/drive/MyDrive/_Phase3'
dest_file_path = os.path.join(dest_dir, 'output_files.zip')

# Create the destination directory if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)
print(f"Destination directory '{dest_dir}' ensured to exist.")

# --- Test write access to the directory ---
test_file = os.path.join(dest_dir, 'test_write.txt')
try:
    with open(test_file, 'w') as f:
        f.write('This is a test file.\n')
    print(f"✅ Successfully wrote test file to '{test_file}'.")
    os.remove(test_file) # Clean up the test file
    print(f"Test file '{test_file}' removed.")
except Exception as e:
    print(f"Error writing test file to '{test_file}': {e}")
    print("⚠️ It seems there might be a permissions or access issue with Google Drive.")
    # Exit or raise an error if write access fails
    raise
# ----------------------------------------

shutil.copy('/content/output_files.zip', dest_file_path)
print(f"📽️ rough_cut.mp4 saved to Google Drive at '{dest_file_path}'.")
