# %%
# Script source: GitHub repo
import os
import shutil

github_url_path = "https://github.com/abdoljh/Lamahat/tree/main/_Phase3"

# Extract the base GitHub repository URL and the subfolder path
def parse_github_path(url):
    parts = url.split('/tree/main/')
    repo_url = parts[0]
    subfolder_path = parts[1] if len(parts) > 1 else ''
    # Add .git for cloning
    repo_url_for_clone = repo_url + '.git'
    return repo_url_for_clone, subfolder_path

repo_url_for_clone, subfolder_path_in_repo = parse_github_path(github_url_path)

repo_name = repo_url_for_clone.split('/')[-1].replace('.git', '')
temp_clone_dir = os.path.join('/tmp', repo_name)
dest_dir_colab = '/content'

print(f"Cloning repository: {repo_url_for_clone}")
print(f"Target subfolder in repo: {subfolder_path_in_repo}")

# Clean up any previous clone to avoid issues
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Removed existing temporary directory: {temp_clone_dir}")

# Clone the repository
clone_command = f"git clone {repo_url_for_clone} {temp_clone_dir}"
print(f"Executing: {clone_command}")
os.system(clone_command)

# Check if cloning was successful
if not os.path.exists(temp_clone_dir):
    print(f"Error: Failed to clone repository {repo_url_for_clone}")
else:
    source_dir_to_copy = os.path.join(temp_clone_dir, subfolder_path_in_repo)
    if not os.path.exists(source_dir_to_copy):
        print(f"Error: Subfolder '{subfolder_path_in_repo}' not found in cloned repository at '{source_dir_to_copy}'")
    else:
        print(f"Source directory to copy: {source_dir_to_copy}")
        print(f"Copying contents of '{source_dir_to_copy}' directly into '{dest_dir_colab}'.")

        # Define directories to skip
        dirs_to_skip = ['artifacts', 'review']

        try:
            for item in os.listdir(source_dir_to_copy):
                if item in dirs_to_skip:
                    print(f"Skipping directory '{item}' as requested.")
                    continue

                source_item_path = os.path.join(source_dir_to_copy, item)
                dest_item_path = os.path.join(dest_dir_colab, item)

                # If item already exists in destination, remove it to avoid errors
                if os.path.exists(dest_item_path):
                    if os.path.isdir(dest_item_path):
                        shutil.rmtree(dest_item_path)
                        print(f"Removed existing directory '{dest_item_path}'.")
                    else:
                        os.remove(dest_item_path)
                        print(f"Removed existing file '{dest_item_path}'.")

                if os.path.isdir(source_item_path):
                    shutil.copytree(source_item_path, dest_item_path)
                else:
                    shutil.copy2(source_item_path, dest_item_path)
                print(f"Copied '{source_item_path}' to '{dest_item_path}'.")
            print(f"Successfully copied contents of '{source_dir_to_copy}' to '{dest_dir_colab}'.")

        except Exception as e:
            print(f"An error occurred during directory contents copy: {e}")

# Clean up the cloned repository
if os.path.exists(temp_clone_dir):
    shutil.rmtree(temp_clone_dir)
    print(f"Cleaned up temporary clone directory: {temp_clone_dir}")
# Out:
# Cloning repository: https://github.com/abdoljh/Lamahat.git
# Target subfolder in repo: _Phase3
# Executing: git clone https://github.com/abdoljh/Lamahat.git /tmp/Lamahat
# Source directory to copy: /tmp/Lamahat/_Phase3
# Copying contents of '/tmp/Lamahat/_Phase3' directly into '/content'.
# Removed existing file '/content/my_jafar.jpg'.
# Copied '/tmp/Lamahat/_Phase3/my_jafar.jpg' to '/content/my_jafar.jpg'.
# Removed existing file '/content/Phase3.md'.
# Copied '/tmp/Lamahat/_Phase3/Phase3.md' to '/content/Phase3.md'.
# Removed existing file '/content/verify_font_discovery.py'.
# Copied '/tmp/Lamahat/_Phase3/verify_font_discovery.py' to '/content/verify_font_discovery.py'.
# Removed existing file '/content/my_book.jpg'.
# Copied '/tmp/Lamahat/_Phase3/my_book.jpg' to '/content/my_book.jpg'.
# Removed existing directory '/content/samples'.
# Copied '/tmp/Lamahat/_Phase3/samples' to '/content/samples'.
# Skipping directory 'artifacts' as requested.
# Removed existing directory '/content/phase3'.
# Copied '/tmp/Lamahat/_Phase3/phase3' to '/content/phase3'.
# Removed existing file '/content/_phase3_b3c.ipynb'.
# Copied '/tmp/Lamahat/_Phase3/_phase3_b3c.ipynb' to '/content/_phase3_b3c.ipynb'.
# Removed existing file '/content/prebuild_assets.py'.
# Copied '/tmp/Lamahat/_Phase3/prebuild_assets.py' to '/content/prebuild_assets.py'.
# Removed existing directory '/content/fonts'.
# Copied '/tmp/Lamahat/_Phase3/fonts' to '/content/fonts'.
# Removed existing file '/content/audit_plan.py'.
# Copied '/tmp/Lamahat/_Phase3/audit_plan.py' to '/content/audit_plan.py'.
# Skipping directory 'review' as requested.
# Removed existing file '/content/INSTALL.md'.
# Copied '/tmp/Lamahat/_Phase3/INSTALL.md' to '/content/INSTALL.md'.
# Removed existing file '/content/phase3_run.py'.
# Copied '/tmp/Lamahat/_Phase3/phase3_run.py' to '/content/phase3_run.py'.
# Removed existing directory '/content/output'.
# Copied '/tmp/Lamahat/_Phase3/output' to '/content/output'.
# Removed existing file '/content/render_plan.py'.
# Copied '/tmp/Lamahat/_Phase3/render_plan.py' to '/content/render_plan.py'.
# Successfully copied contents of '/tmp/Lamahat/_Phase3' to '/content'.
# Cleaned up temporary clone directory: /tmp/Lamahat

# %%
# Verify font discovery (OPTIONAL)
# !python verify_font_discovery.py

# %%
# Check font paths (OPTIONAL)
# !python -c "from phase3.typography import FONT_PATHS; print(FONT_PATHS)"
# print("✅ Pre-testingvthe discovery of Amiri fonts completed!")

# %%
# !pip install anthropic
print("✴️ Anthropic installed!")
# Out:
# Requirement already satisfied: anthropic in /usr/local/lib/python3.12/dist-packages (0.102.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# ✴️ Anthropic installed!

# %%
# !pip install whisperx openai-whisper
# print("✅ whisperx and openai-whisper installed!")

# %%
# !pip install arabic-reshaper python-bidi
# print("✅ Arabic_reshaper and python-bidi installed!")

# %%
print("Retrieving the Anthropic & Pexels API keys ...")
from google.colab import userdata
import os

# Retrieve the Anthropic API key from Colab Secrets
anthropic_api_key = userdata.get('ANTHROPIC_API_KEY')
pexels_api_key = userdata.get('PEXELS_API_KEY')

# Set it as an environment variable for phase3_run.py to use
if anthropic_api_key:
    os.environ['ANTHROPIC_API_KEY'] = anthropic_api_key
    print("🔑 Anthropic API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: ANTHROPIC_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")

if pexels_api_key:
    os.environ['PEXELS_API_KEY'] = pexels_api_key
    print("🔑 Pexels API key loaded from secrets and set as environment variable.")
else:
    print("❌ Warning: PEXELS_API_KEY not found in Colab Secrets. Please ensure it's set correctly.")
# Out:
# Retrieving the Anthropic & Pexels API keys ...
# 🔑 Anthropic API key loaded from secrets and set as environment variable.
# 🔑 Pexels API key loaded from secrets and set as environment variable.

# %%
# Confirm alignment works (interpolation backend — no install needed)
# !python phase3_run.py \
    --script samples/al_askari_script.txt \
    --audio output/al_askari_audio.mp3 \
    --align-only \
    --align-backend interpolated

print("✅ Confirming alignment completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,045 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
# Backend: interpolated
#
# ── Running alignment ──────────────────────────────────────────────
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#
#   Aligned 653 words in 0.0 s
#   Backend used: interpolated
#
# ── First 30 word timings ──────────────────────────────────────────
#      0.00s →    1.18s   (1.18s)   مُذَكِّرات
#      1.18s →    1.65s   (0.47s)   جعفر
#      1.65s →    2.60s   (0.95s)   العسكريْ
#      2.60s →    2.95s   (0.35s)   رجل
#      2.95s →    3.43s   (0.47s)   واحد
#      3.43s →    3.78s   (0.35s)   حمل
#      3.78s →    4.49s   (0.71s)   سلاحاً
#      4.49s →    4.73s   (0.24s)   من
#      4.73s →    5.08s   (0.35s)   أجل
#      5.08s →    5.67s   (0.59s)   تحرير
#      5.67s →    6.26s   (0.59s)   وطنه،
#      6.26s →    6.74s   (0.47s)   لكنه
#      6.74s →    7.45s   (0.71s)   اكتشفَ
#      7.45s →    7.92s   (0.47s)   أنَّ
#      7.92s →    8.39s   (0.47s)   أشرس
#      8.39s →    9.22s   (0.83s)   الأعداء
#      9.22s →    9.46s   (0.24s)   قد
#      9.46s →   10.17s   (0.71s)   يكونون
#     10.17s →   10.40s   (0.24s)   من
#     10.40s →   10.87s   (0.47s)   داخل
#     10.87s →   11.47s   (0.59s)   صفوفك
#     11.47s →   11.82s   (0.35s)   هذه
#     11.82s →   12.29s   (0.47s)   ليست
#     12.29s →   12.88s   (0.59s)   رواية
#     12.88s →   13.36s   (0.47s)   خيال
#     13.36s →   14.18s   (0.83s)   تاريخي،
#     14.18s →   14.42s   (0.24s)   بل
#     14.42s →   15.13s   (0.71s)   شهادةٌ
#     15.13s →   15.72s   (0.59s)   حيّةٌ
#     15.72s →   15.96s   (0.24s)   من
#   … and 623 more
#
# Word timings → output/word_timings.json
# ✅ Confirming alignment completed!

# %%
# Step 1: plan as before — produces output/al_askari_plan_v2.json
# Regenerate the plan with the fixes
# !python phase3_run.py \
    --script  samples/al_askari_script.txt \
    --audio   output/al_askari_audio.mp3 \
    --book-title "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --plan-only \
    --save-plan output/al_askari_plan_v2.json

print("✅ Regenerating the plan completed!")
# Out:
# Script : samples/al_askari_script.txt  (4,045 chars)
#
# Script : 653 word tokens, 2 sections
# Audio  : output/al_askari_audio.mp3
# Total  : 391.0 s
#
# ── Step 1: Forced alignment ───────────────────────────────────────
# WARNING  phase3.align  Backend whisperx failed: No module named 'whisperx'
# WARNING  phase3.align  Backend whisper failed: No module named 'whisper'
# WARNING  phase3.align  Using interpolated timings — character-rate estimates only. For real word-level accuracy, install whisperx (pip install whisperx) or whisper (pip install openai-whisper).
#   653 words aligned via interpolated (0.0s)
#
# ── Step 2: AI shot planner ────────────────────────────────────────
# INFO  phase3.plan  Calling claude-sonnet-4-6 for shot plan (target=65 shots, 5.0s avg, 391.0s total)
# INFO  httpx  HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO  phase3.plan  Normalised 2 shot(s) with conflicting fields
# INFO  phase3.plan  Clipping shot 378.00-391.00s to 391.00s (audio end)
# INFO  phase3.plan  Merged 4 adjacent identical shot(s) — final plan 48 shots
# INFO  phase3.plan  Plan produced: 48 shots
#   48 shots planned in 88.9s
#
# Plan: 48 shots, 391.0s total
# ────────────────────────────────────────────────────────────────────────────────────────────
# Visuals: typography:18  archive:9  portrait:5  location:5  section_mark:4  broll:3  title_card:2  object:2
# ────────────────────────────────────────────────────────────────────────────────────────────
#     1. [  opening]   0.00-  3.78s ( 3.8s) title_card     static_hold
#     2. [  opening]   3.78-  9.22s ( 5.4s) typography     static_hold   "رجل واحد حمل سلاحاً من أجل تحرير وطنه، لكنه اكتشفَ"
#     3. [  opening]   9.22- 15.72s ( 6.5s) archive        slow_push     Ottoman Empire soldiers historical photo 1910
#     4. [  opening]  15.72- 22.46s ( 6.7s) typography     static_hold   "شهادةٌ حيّةٌ من قلب أحداثٍ غيّرت وجهَ المنطقة العر"
#     5. [  opening]  22.46- 30.38s ( 7.9s) portrait       static_hold   Jafar al-Askari Iraqi military officer portrait historical
#     6. [  opening]  30.38- 36.76s ( 6.4s) archive        slow_push     Ottoman Empire collapse Arab nationalism historical document
#     7. [  opening]  36.76- 44.44s ( 7.7s) typography     static_hold   "كيف يصنع العسكري ثورة؟ وماذا يفعل عندما يقف بين ول"
#     8. [  opening]  44.44- 51.30s ( 6.9s) location       pan_right     Mosul Iraq historical city photograph 1900s
#     9. [  opening]  51.30- 55.79s ( 4.5s) section_mark   static_hold
#    10. [  opening]  55.79- 62.29s ( 6.5s) location       slow_push     Mosul Iraq street 1904 historical Ottoman era
#    11. [  opening]  62.29- 68.79s ( 6.5s) location       pan_left      Istanbul Constantinople Ottoman military academy 1900s histo
#    12. [  opening]  68.79- 75.53s ( 6.7s) typography     static_hold   "عبوراً من عالم تقليدي إلى آفاق حديثة مليئة بالمناه"
#    13. [  opening]  75.53- 82.86s ( 7.3s) archive        slow_push     Ottoman military academy cadets Istanbul 1900s classroom
#    14. [  opening]  82.86- 91.25s ( 8.4s) broll          slow_push     Arab officers Egypt Syria Iraq gathering historical 1900s
#    15. [  opening]  91.25-101.41s (10.2s) typography     static_hold   "جميعهم يحملون حلماً واحداً إصلاح الجيش والدولة من "
#    16. [  opening] 101.41-110.63s ( 9.2s) portrait       static_hold   Mahmud Shawkat Pasha Ottoman general historical portrait
#    17. [  opening] 110.63-120.21s ( 9.6s) archive        slow_push     Ottoman Empire military reform modernisation documents 1908
#    18. [  opening] 120.21-130.73s (10.5s) typography     static_hold   "الإصلاح الحقيقي لا يتوقف على التسليح والتَّكْتِيكا"
#    19. [  opening] 130.73-141.72s (11.0s) broll          slow_push     Arab youth military education historical books documents 190
#    20. [  opening] 141.72-147.51s ( 5.8s) section_mark   static_hold
#    21. [  opening] 147.51-155.08s ( 7.6s) location       slow_push     Istanbul Constantinople Ottoman political intrigue 1908 hist
#    22. [  opening] 155.08-163.59s ( 8.5s) archive        slow_push     Committee of Union and Progress CUP Young Turks 1908 revolut
#    23. [  opening] 163.59-171.62s ( 8.0s) typography     static_hold   "انقلاب ١٩٠٨ الشهير، الذي أطاح بالسلطان عبدالحميد ا"
#    24. [  opening] 171.62-180.37s ( 8.7s) archive        slow_push     Sultan Abdulhamid II deposed 1909 Ottoman Empire historical
#    25. [  opening] 180.37-188.76s ( 8.4s) typography     static_hold   "رأى بعينيه كيف يمكن لقوة عسكرية منظمة أن تغيّر مسا"
#    26. [  opening] 188.76-197.63s ( 8.9s) portrait       static_hold   Jafar al-Askari Iraqi officer early career uniform historica
#    27. [  opening] 197.63-207.44s ( 9.8s) typography     static_hold   "النظام الجديد حمل فساداً من نوع آخر، ومصالح شخصية "
#    28. [  opening] 207.44-215.24s ( 7.8s) broll          slow_push     Ottoman political intrigue corruption officials historical d
#    29. [  opening] 215.24-225.76s (10.5s) typography     static_hold   "صراع الضميرين ضمير الجندي الوفي لدولته وضمير الوطن"
#    30. [  opening] 225.76-233.09s ( 7.3s) section_mark   static_hold
#    31. [  opening] 233.09-240.42s ( 7.3s) archive        fast_push     Balkan Wars 1912 Ottoman soldiers battlefield historical pho
#    32. [  opening] 240.42-250.34s ( 9.9s) typography     static_hold   "هل يبقى جندياً وفياً للدولةِ العثمانيةِ المتداعية،"
#    33. [  opening] 250.34-258.26s ( 7.9s) location       pan_right     Libya North Africa desert Senussi movement World War One 191
#    34. [  opening] 258.26-265.00s ( 6.7s) archive        slow_push     Senussi movement Libya Arab fighters World War One historica
#    35. [  opening] 265.00-275.76s (10.8s) typography     static_hold   "المذكرات تروي بتفاصيل دقيقة كيفية إدارة هذه العملي"
#    36. [  opening] 275.76-283.32s ( 7.6s) portrait       static_hold   Jafar al-Askari Arab Revolt World War One military commander
#    37. [  opening] 283.32-293.13s ( 9.8s) typography     static_hold   "تاريخ الشرق الأوسط الحديث مكتوب جزئياً من خلال قرا"
#    38. [  closing] 293.13-296.21s ( 3.1s) section_mark   static_hold
#    39. [  closing] 296.21-304.12s ( 7.9s) object         slow_push     Arabic memoir book open pages historical manuscript close-up
#    40. [  closing] 304.12-315.35s (11.2s) typography     static_hold   "دعوة للتأمل العميق حول طبيعة الولاء والوطنية، وحول"
#    41. [  closing] 315.35-324.46s ( 9.1s) portrait       static_hold   Jafar al-Askari Iraqi statesman 1920s Baghdad portrait
#    42. [  closing] 324.46-331.55s ( 7.1s) archive        slow_push     Arab history modern Middle East World War One Ottoman archiv
#    43. [  closing] 331.55-341.00s ( 9.5s) typography     static_hold   "الكتاب يضم مقدمة تحليلية عميقة، وستة عشر فصلاً منظ"
#    44. [  closing] 341.00-348.80s ( 7.8s) object         slow_push     historical maps letters documents Middle East archive World
#    45. [  closing] 348.80-359.68s (10.9s) typography     static_hold   "بين دفتي هذا الكتاب ستجد نقاشاً صريحاً عن الفساد و"
#    46. [  closing] 359.68-368.66s ( 9.0s) typography     static_hold   "ستلتقي برجل حقيقي، لا بطلٍ أسطوري، بل برجل تَرَدَّ"
#    47. [  closing] 368.66-378.00s ( 9.3s) typography     static_hold   "هذه شهادة حية من قلب التاريخ، وأدعوك بصراحة تامة أ"
#    48. [  closing] 378.00-391.00s (13.0s) title_card     static_hold
#
# Shot plan → output/al_askari_plan_v2.json
# Word timings → output/word_timings.json
# ✅ Regenerating the plan completed!

# %%
# Audit it
# !python audit_plan.py output/al_askari_plan_v2.json
# Expect: ~43 shots, <10% auto-split

print("✅ Audit completed!")
# Out:
# ======================================================================
# PLAN AUDIT
# ======================================================================
#
# Total shots:        48
# Plan timeline:      0.00s → 391.00s (391.0s)
# Average shot:       8.15s
# Range:              3.07s – 13.00s
#
# ✓  No gaps or overlaps
#
# Visual types:
#    typography      18 (  38%) ███████████
#    archive          9 (  19%) █████
#    portrait         5 (  10%) ███
#    location         5 (  10%) ███
#    section_mark     4 (   8%) ██
#    broll            3 (   6%) █
#    title_card       2 (   4%) █
#    object           2 (   4%) █
#
# Motion types:
#    static_hold     29 (  60%) ██████████████████
#    slow_push       15 (  31%) █████████
#    pan_right        2 (   4%) █
#    pan_left         1 (   2%)
#    fast_push        1 (   2%)
#
# Section coverage:
#    opening         37 shots
#    closing         11 shots
#
# ✓  Auto-split shots: 3/48 (6%) from 3 original(s)
#      Implied original Sonnet shot count: 48
#
# Typography texts: 24 unique (24 occurrences after splits)
#    Word count: min=3, max=23, avg=13.4
#    Templates: chapter_heading:6, pull_quote:17, date_stamp:1
#
#
# Search queries: 24 non-empty, avg 8.1 words
#    ✓ Bare (1–2 words): 0 (none — good specificity)
#
# ======================================================================
# ✅ Audit completed!

# %%
import os

# Step 2 (NEW): prebuild — run every source, score every candidate,
# write a review dossier.  No video render.
# !python prebuild_assets.py \
    --plan          output/al_askari_plan_v2.json \
    --script        samples/al_askari_script.txt \
    --book-title    "مذكرات جعفر العسكري" \
    --character-name "Jafar al-Askari" \
    --anthropic-key "$ANTHROPIC_API_KEY" \
    --pexels-key    "$PEXELS_API_KEY" \
    --review-dir    output/review/ \
    --character-portrait my_jafar.jpg
# Out:
# INFO    phase3.prebuild  Loaded plan: 48 shots
# INFO    phase3.prebuild  Image-needing shots: 24 (the rest are typography)
# INFO    phase3.prebuild  Pinned portrait copied → /content/output/review/overrides/character.jpg
# INFO    phase3.prebuild  Shot 3/archive: query='Ottoman Empire soldiers historical photo 1910' duration=6.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire soldiers historical photo 1910'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire soldiers historical photo 1910'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire soldiers historical photo 1910'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire soldiers historical photo 1910'
# INFO    phase3.sources.vision  Vision 1/2/2  Close-up of bronze Ottoman soldier statu  — Bronze statues of uniformed soldiers from correct historical
# INFO    phase3.sources.vision  Vision 3/2/2  Sepia-toned vintage photo of a man in un  — Authentic Ottoman-era mounted soldier photograph matching th
# INFO    phase3.sources.vision  Vision 1/3/3  Turkish warrior in armor riding a horse,  — Modern photograph of Turkish flag and medieval warrior statu
# INFO    phase3.sources  Shot 3: best=Sepia-toned vintage photo of a man in uniform ridi (score 7)
# INFO    phase3.prebuild  Shot 5/portrait: query='Jafar al-Askari Iraqi military officer portrait historical' duration=7.9s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi military officer portrait historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi military officer portrait historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi military officer portrait historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi military officer portrait historical'
# INFO    phase3.sources.vision  Vision 2/3/3  Portrait of a man in a historical milita  — Period military uniform and styling evoke early 20th-century
# INFO    phase3.sources.vision  Vision 3/3/3  Man in a detailed historical officer uni  — Authentic period military uniform with gold embroidery and i
# INFO    phase3.sources.vision  Vision 1/3/2  Indonesian military officer smiling in f  — Modern military portrait with correct insignia and uniform s
# INFO    phase3.sources  Shot 5: best=Man in a detailed historical officer uniform stand (score 9)
# INFO    phase3.prebuild  Shot 6/archive: query='Ottoman Empire collapse Arab nationalism historical document' duration=6.4s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire collapse Arab nationalism historical document 1914'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire collapse Arab nationalism historical document 1914'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire collapse Arab nationalism historical document 1914'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire collapse Arab nationalism historical document 1914'
# INFO    phase3.sources.vision  Vision 3/2/2  Detailed close-up of Arabic calligraphy   — Authentic Ottoman-era Arabic manuscript with geometric diagr
# INFO    phase3.sources.vision  Vision 3/2/2  Detailed image of ancient Arabic calligr  — Authentic Ottoman-era Arabic manuscript with decorative elem
# INFO    phase3.sources.vision  Vision 2/3/3  Turkish warrior in armor riding a horse,  — Turkish flag and mounted warrior evoke Ottoman historical co
# INFO    phase3.sources  Shot 6: best=Turkish warrior in armor riding a horse, holding a (score 8)
# INFO    phase3.prebuild  Shot 8/location: query='Mosul Iraq historical city photograph 1900s' duration=6.9s
# WARNING phase3.sources.loc  LoC search failed for 'Mosul Iraq historical city photograph 1900s': The read operation timed out
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mosul Iraq historical city photograph 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mosul Iraq historical city photograph 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mosul Iraq historical city photograph 1900s'
# INFO    phase3.sources.vision  Vision 3/2/3  Explore the historic ruins of ancient Ba  — Authentic historical/architectural view of fortified Iraqi c
# INFO    phase3.sources.vision  Vision 2/3/3  A striking black and white aerial view s  — Historic black-and-white urban photograph of Middle Eastern
# INFO    phase3.sources.vision  Vision 2/3/2  Aerial view of densely packed historic c  — Authentic aerial view of a dense Middle Eastern city with tr
# INFO    phase3.sources  Shot 8: best=Explore the historic ruins of ancient Babylon unde (score 8)
# INFO    phase3.prebuild  Shot 10/location: query='Mosul Iraq street 1904 historical Ottoman era' duration=6.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mosul Iraq street 1904 historical Ottoman era'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mosul Iraq street 1904 historical Ottoman era'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mosul Iraq street 1904 historical Ottoman era'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mosul Iraq street 1904 historical Ottoman era'
# INFO    phase3.sources.vision  Vision 2/2/3  Explore the rustic charm of a historic t  — Ottoman-era architecture in apparent Middle Eastern decay, f
# INFO    phase3.sources.vision  Vision 2/3/3  Vibrant Ottoman-style houses on a snowy   — Authentic Ottoman-era architecture in correct region/period,
# INFO    phase3.sources.vision  Vision 2/3/3  Traditional Ottoman-style lanterns hangi  — Authentically aged Ottoman-era street scene with period obje
# INFO    phase3.sources  Shot 10: best=Vibrant Ottoman-style houses on a snowy street in  (score 8)
# INFO    phase3.prebuild  Shot 11/location: query='Istanbul Constantinople Ottoman military academy 1900s histo' duration=6.5s
# WARNING phase3.sources.loc  LoC search failed for 'Istanbul Constantinople Ottoman military academy 1900s historical': The read operation timed out
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Istanbul Constantinople Ottoman military academy 1900s historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Istanbul Constantinople Ottoman military academy 1900s historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Istanbul Constantinople Ottoman military academy 1900s historical'
# INFO    phase3.sources.vision  Vision 3/3/3  Historic Kuleli Military School on the B  — Iconic Ottoman-era waterfront palace architecture (Kuleli Mi
# INFO    phase3.sources.vision  Vision 2/2/2  Fener Greek High School building in Bala  — Ottoman-era architecture in Istanbul matches historical peri
# INFO    phase3.sources.vision  Vision 3/3/3  Stunning view of Kuleli Military High Sc  — Iconic Ottoman waterfront military building (Kuleli Barracks
# INFO    phase3.sources  Shot 11: best=Historic Kuleli Military School on the Bosphorus i (score 9)
# INFO    phase3.prebuild  Shot 13/archive: query='Ottoman military academy cadets Istanbul 1900s classroom' duration=7.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman military academy cadets Istanbul 1900s classroom'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman military academy cadets Istanbul 1900s classroom'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman military academy cadets Istanbul 1900s classroom'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman military academy cadets Istanbul 1900s classroom'
# INFO    phase3.sources.vision  Vision 1/3/2  Historic Kuleli Military School on the B  — Ottoman-era waterfront palace matches historical period and
# INFO    phase3.sources.vision  Vision 1/2/2  Close-up of bronze Ottoman soldier statu  — Bronze statues of Ottoman-era military figures match the his
# INFO    phase3.sources.vision  Vision 2/3/2  Photograph of a historical building in E  — Ottoman-era military building with period architecture and T
# INFO    phase3.sources  Shot 13: best=Photograph of a historical building in Edirne, Tur (score 7)
# INFO    phase3.prebuild  Shot 14/broll: query='Arab officers Egypt Syria Iraq gathering historical 1900s' duration=8.4s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab officers Egypt Syria Iraq gathering historical 1900s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab officers Egypt Syria Iraq gathering historical 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab officers Egypt Syria Iraq gathering historical 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab officers Egypt Syria Iraq gathering historical 1900s'
# INFO    phase3.sources.vision  Vision 2/2/3  Local men enjoy a casual gathering outsi  — Right era and region (Arab world, early-mid 20th century aes
# INFO    phase3.sources.vision  Vision 1/2/2  A group of men holding Syrian flags rall  — Modern protest scene with Syrian flags; geographically relev
# INFO    phase3.sources.vision  Vision 2/2/2  Lively street in Alexandria, Egypt with   — Authentic Middle Eastern street scene with period architectu
# INFO    phase3.sources  Shot 14: best=Local men enjoy a casual gathering outside a café  (score 7)
# INFO    phase3.prebuild  Shot 16/portrait: query='Mahmud Shawkat Pasha Ottoman general historical portrait' duration=9.2s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Mahmud Shawkat Pasha Ottoman general historical portrait'
# INFO    phase3.sources.vision  Vision 1/3/3  Intricate frescoes and architecture of K  — Ornate Ottoman-era mosque interior is regionally and tempora
# INFO    phase3.sources.vision  Vision 1/3/3  View of the detailed dome and Arabic cal  — Ottoman architectural interior is period-appropriate context
# INFO    phase3.sources.vision  Vision 1/3/3  Explore the intricate architecture and d  — Ottoman-era architectural interior is contextually relevant
# INFO    phase3.sources  Shot 16: best=Intricate frescoes and architecture of Kılıç Ali P (score 7)
# INFO    phase3.prebuild  Shot 17/archive: query='Ottoman Empire military reform modernisation documents 1908' duration=9.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman Empire military reform modernisation documents 1908'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman Empire military reform modernisation documents 1908'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman Empire military reform modernisation documents 1908'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman Empire military reform modernisation documents 1908'
# INFO    phase3.sources.vision  Vision 2/3/3  Turkish warrior in armor riding a horse,  — Ottoman Turkish flag with mounted soldier evokes the period
# INFO    phase3.sources.vision  Vision 1/3/2  Stunning architectural view of Hagia Sop  — Historic Ottoman-era architecture suggests right period/regi
# INFO    phase3.sources.vision  Vision 1/2/2  Close-up of bronze Ottoman soldier statu  — Bronze statues of Ottoman-era military figures suggest the c
# INFO    phase3.sources  Shot 17: best=Turkish warrior in armor riding a horse, holding a (score 8)
# INFO    phase3.prebuild  Shot 19/broll: query='Arab youth military education historical books documents 190' duration=11.0s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arab youth military education historical books documents 1900s'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab youth military education historical books documents 1900s'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab youth military education historical books documents 1900s'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab youth military education historical books documents 1900s'
# INFO    phase3.sources.vision  Vision 3/2/2  Close-up view of Arabic script on a book  — Authentic historical Arabic text document matching the Jafar
# INFO    phase3.sources.vision  Vision 3/3/3  A visually captivating still life featur  — Authentic historical Arabic manuscript with rich period atmo
# INFO    phase3.sources.vision  Vision 3/2/2  Explore a classic open book surrounded b  — Authentic historical documents in Arabic (likely early 20th-
# INFO    phase3.sources  Shot 19: best=A visually captivating still life featuring a vint (score 9)
# INFO    phase3.prebuild  Shot 21/location: query='Istanbul Constantinople Ottoman political intrigue 1908 hist' duration=7.6s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Istanbul Constantinople Ottoman political intrigue 1908 historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Istanbul Constantinople Ottoman political intrigue 1908 historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Istanbul Constantinople Ottoman political intrigue 1908 historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Istanbul Constantinople Ottoman political intrigue 1908 historical'
# INFO    phase3.sources.vision  Vision 2/3/3  A picturesque view of the Hagia Sophia a  — Istanbul skyline with Hagia Sophia captures correct historic
# INFO    phase3.sources.vision  Vision 3/2/3  Grayscale image capturing the iconic Hag  — Authentic historical photograph of Istanbul's skyline with H
# INFO    phase3.sources.vision  Vision 2/3/3  Fener Greek High School building in Bala  — Ottoman-era architecture in Istanbul perfectly evokes early
# INFO    phase3.sources  Shot 21: best=Grayscale image capturing the iconic Hagia Sophia  (score 8)
# INFO    phase3.prebuild  Shot 22/archive: query='Committee of Union and Progress CUP Young Turks 1908 revolut' duration=8.5s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Committee of Union and Progress CUP Young Turks 1908 revolution Istanbul'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Committee of Union and Progress CUP Young Turks 1908 revolution Istanbul'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Committee of Union and Progress CUP Young Turks 1908 revolution Istanbul'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Committee of Union and Progress CUP Young Turks 1908 revolution Istanbul'
# INFO    phase3.sources.vision  Vision 1/2/2  A serene street in Heybeliada, featuring  — Modern Istanbul street scene with Turkish flag and belle épo
# INFO    phase3.sources.vision  Vision 1/2/2  Stylish young woman poses at İstanbul's   — Modern portrait in Istanbul setting with period costume elem
# INFO    phase3.sources.vision  Vision 1/2/2  View through a window with the Turkish f  — Turkish flag visible suggests Ottoman/Turkish context, but i
# INFO    phase3.sources  Shot 22: best=A serene street in Heybeliada, featuring the Turki (score 5)
# INFO    phase3.prebuild  Shot 24/archive: query='Sultan Abdulhamid II deposed 1909 Ottoman Empire historical ' duration=8.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Sultan Abdulhamid II deposed 1909 Ottoman Empire historical photo'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Sultan Abdulhamid II deposed 1909 Ottoman Empire historical photo'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Sultan Abdulhamid II deposed 1909 Ottoman Empire historical photo'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Sultan Abdulhamid II deposed 1909 Ottoman Empire historical photo'
# INFO    phase3.sources.vision  Vision 1/2/2  Close-up of bronze Ottoman soldier statu  — Bronze statues of Ottoman-era military figures show correct
# INFO    phase3.sources.vision  Vision 2/3/3  Ornate gate of Dolmabahçe Palace, Istanb  — Ottoman architectural masterpiece from the Abdulhamid II era
# INFO    phase3.sources.vision  Vision 2/3/2  Scenic view of Topkapi Palace from the B  — Ottoman-era waterfront palace architecture matches historica
# INFO    phase3.sources  Shot 24: best=Ornate gate of Dolmabahçe Palace, Istanbul, showca (score 8)
# INFO    phase3.prebuild  Shot 26/portrait: query='Jafar al-Askari Iraqi officer early career uniform historica' duration=8.9s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi officer early career uniform historical'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi officer early career uniform historical'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi officer early career uniform historical'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi officer early career uniform historical'
# INFO    phase3.sources.vision  Vision 3/3/3  Man in a detailed historical officer uni  — Historically accurate Ottoman-style military uniform with go
# INFO    phase3.sources.vision  Vision 2/3/3  An Argentinian guard in formal attire po  — Period military uniform and setting evoke early 20th century
# INFO    phase3.sources.vision  Vision 2/3/3  Portrait of a man in a historical milita  — Period military uniform with Ottoman-influenced styling matc
# INFO    phase3.sources  Shot 26: best=Man in a detailed historical officer uniform stand (score 9)
# INFO    phase3.prebuild  Shot 28/broll: query='Ottoman political intrigue corruption officials historical d' duration=7.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Ottoman political intrigue corruption officials historical documents'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Ottoman political intrigue corruption officials historical documents'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Ottoman political intrigue corruption officials historical documents'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Ottoman political intrigue corruption officials historical documents'
# INFO    phase3.sources.vision  Vision 3/3/3  Red leather-bound parliamentary books fr  — Antique leather-bound Ottoman-era documents with gilt letter
# INFO    phase3.sources.vision  Vision 2/3/2  Elegant Ottoman-style building in Istanb  — Ottoman-era institutional architecture relevant to period an
# INFO    phase3.sources.vision  Vision 2/3/3  Entrance of the historic Kurşunlu Han in  — Ottoman-era administrative building with strong architectura
# INFO    phase3.sources  Shot 28: best=Red leather-bound parliamentary books from 19th ce (score 9)
# INFO    phase3.prebuild  Shot 31/archive: query='Balkan Wars 1912 Ottoman soldiers battlefield historical pho' duration=7.3s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Balkan Wars 1912 Ottoman soldiers battlefield historical photograph'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Balkan Wars 1912 Ottoman soldiers battlefield historical photograph'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Balkan Wars 1912 Ottoman soldiers battlefield historical photograph'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Balkan Wars 1912 Ottoman soldiers battlefield historical photograph'
# INFO    phase3.sources.vision  Vision 1/3/2  Group of reenactors depicting historical  — Modern reenactment of historical military scene with excelle
# INFO    phase3.sources.vision  Vision 1/3/3  Bronze statue and relief honoring Turkis  — Monument depicts soldiers and flags from Ottoman era, releva
# INFO    phase3.sources.vision  Vision 1/3/2  Three soldiers in vintage uniforms reena  — Modern reenactment with period costumes in natural setting;
# INFO    phase3.sources  Shot 31: best=Bronze statue and relief honoring Turkish martyrs  (score 7)
# INFO    phase3.prebuild  Shot 33/location: query='Libya North Africa desert Senussi movement World War One 191' duration=7.9s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Libya North Africa desert Senussi movement World War One 1915'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Libya North Africa desert Senussi movement World War One 1915'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Libya North Africa desert Senussi movement World War One 1915'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Libya North Africa desert Senussi movement World War One 1915'
# INFO    phase3.sources.vision  Vision 2/3/3  Footprints trail across sand dunes in Mo  — Desert landscape with footprints evokes North Africa setting
# INFO    phase3.sources.vision  Vision 2/3/3  Explore the iconic desert landscape of t  — Authentic North African desert landscape with historical arc
# INFO    phase3.sources.vision  Vision 2/2/2  Camels feed in the arid landscape of Al   — Authentic North African desert landscape with period-appropr
# INFO    phase3.sources  Shot 33: best=Footprints trail across sand dunes in Morocco's Ks (score 8)
# INFO    phase3.prebuild  Shot 34/archive: query='Senussi movement Libya Arab fighters World War One historica' duration=6.7s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Senussi movement Libya Arab fighters World War One historical photo'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Senussi movement Libya Arab fighters World War One historical photo'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Senussi movement Libya Arab fighters World War One historical photo'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Senussi movement Libya Arab fighters World War One historical photo'
# INFO    phase3.sources.vision  Vision 0/2/3  Libyan soldiers holding rifles and red f  — Modern staged military photograph with dramatic red lighting
# INFO    phase3.sources.vision  Vision 1/3/3  Bronze statue and relief honoring Turkis  — Monument depicts Soviet-era military commemoration with Arab
# INFO    phase3.sources.vision  Vision 2/3/3  A soldier in uniform holding a rifle aga  — Period-appropriate military costume and WWI-era weaponry in
# INFO    phase3.sources  Shot 34: best=A soldier in uniform holding a rifle against a dra (score 8)
# INFO    phase3.prebuild  Shot 36/portrait: query='Jafar al-Askari Arab Revolt World War One military commander' duration=7.6s
# WARNING phase3.sources.loc  LoC search failed for 'Jafar al-Askari Arab Revolt World War One military commander portrait': The read operation timed out
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Arab Revolt World War One military commander portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Arab Revolt World War One military commander portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Arab Revolt World War One military commander portrait'
# INFO    phase3.sources.vision  Vision 2/3/3  A soldier in uniform holding a rifle aga  — Period-appropriate WWI military portraiture with authentic O
# INFO    phase3.sources.vision  Vision 2/3/3  Two riders in military attire on horseba  — Period-appropriate WWI military scene with mounted cavalry i
# INFO    phase3.sources.vision  Vision 2/3/3  Black and white photo of Soviet soldiers  — WWI-era military officer in period uniform with aircraft, co
# INFO    phase3.sources  Shot 36: best=A soldier in uniform holding a rifle against a dra (score 8)
# INFO    phase3.prebuild  Shot 39/object: query='Arabic memoir book open pages historical manuscript close-up' duration=7.9s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Arabic memoir book open pages historical manuscript close-up'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arabic memoir book open pages historical manuscript close-up'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arabic memoir book open pages historical manuscript close-up'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arabic memoir book open pages historical manuscript close-up'
# INFO    phase3.sources.vision  Vision 3/3/3  Detailed view of an ancient illuminated   — Authentic historical Arabic manuscript with ornate calligrap
# INFO    phase3.sources.vision  Vision 3/2/2  A close-up of an antique open book with   — Authentic historical manuscript matching the exact request—o
# INFO    phase3.sources.vision  Vision 3/3/3  Open ancient manuscript on red backgroun  — Authentically aged Arabic manuscript photographed with drama
# INFO    phase3.sources  Shot 39: best=Detailed view of an ancient illuminated manuscript (score 9)
# INFO    phase3.prebuild  Shot 41/portrait: query='Jafar al-Askari Iraqi statesman 1920s Baghdad portrait' duration=9.1s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'Jafar al-Askari Iraqi statesman 1920s Baghdad portrait'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Jafar al-Askari Iraqi statesman 1920s Baghdad portrait'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Jafar al-Askari Iraqi statesman 1920s Baghdad portrait'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Jafar al-Askari Iraqi statesman 1920s Baghdad portrait'
# INFO    phase3.sources.vision  Vision 1/3/2  Man in a tuxedo smiling indoors in a lux  — Modern formal portrait in period-appropriate setting, but co
# INFO    phase3.sources.vision  Vision 1/3/2  A handsome man in evening wear smiling i  — Modern studio portrait in formal attire suggests early 20th
# INFO    phase3.sources.vision  Vision 1/2/2  Profile portrait of a man in a tuxedo in  — Formal portrait with period styling fits 1920s aesthetic but
# INFO    phase3.sources  Shot 41: best=Man in a tuxedo smiling indoors in a luxurious, or (score 6)
# INFO    phase3.prebuild  Shot 42/archive: query='Arab history modern Middle East World War One Ottoman archiv' duration=7.1s
# WARNING phase3.sources.loc  LoC search failed for 'Arab history modern Middle East World War One Ottoman archive 1920': The read operation timed out
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'Arab history modern Middle East World War One Ottoman archive 1920'
# INFO    phase3.sources.internet_archive  Internet Archive: 0 candidates for 'Arab history modern Middle East World War One Ottoman archive 1920'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'Arab history modern Middle East World War One Ottoman archive 1920'
# INFO    phase3.sources.vision  Vision 2/2/3  A haunting view of abandoned and destroy  — Ruined Ottoman-era Middle Eastern architecture evokes region
# INFO    phase3.sources.vision  Vision 1/3/2  Upward view of the Çanakkale Martyrs' Me  — Turkish flag in modern concrete structure is tangentially re
# INFO    phase3.sources.vision  Vision 3/3/3  Red leather-bound parliamentary books fr  — Authentic archival leather-bound volumes with visible Arabic
# INFO    phase3.sources  Shot 42: best=Red leather-bound parliamentary books from 19th ce (score 9)
# INFO    phase3.prebuild  Shot 44/object: query='historical maps letters documents Middle East archive World ' duration=7.8s
# INFO    phase3.sources.loc  LoC: 0 candidates for 'historical maps letters documents Middle East archive World War One'
# INFO    phase3.sources.wikimedia  Wikimedia: 0 candidates for 'historical maps letters documents Middle East archive World War One'
# INFO    phase3.sources.internet_archive  Internet Archive: 1 candidates for 'historical maps letters documents Middle East archive World War One'
# INFO    phase3.sources.pexels  Pexels: 3 candidates for 'historical maps letters documents Middle East archive World War One'
# WARNING phase3.sources.base  Source internet_archive: download failed for https://archive.org/download/majestic-12-files/majestic-12-files.jpg: HTTP Error 404: Not Found
# INFO    phase3.sources.vision  Vision 3/3/3  A close-up of a vintage map, magnifying   — Perfect match: vintage maps with magnifying glass, notebook,
# INFO    phase3.sources.vision  Vision 2/3/3  A nostalgic flat lay combining vintage t  — Vintage travel/archive aesthetic perfectly evokes WWI-era ex
# INFO    phase3.sources.vision  Vision 2/2/2  Colorful world map close-up showing Afri  — Period-appropriate historical map of Middle East region with
# INFO    phase3.sources  Shot 44: best=A close-up of a vintage map, magnifying glass, and (score 9)
# INFO    phase3.sources.decisions  Decisions written → /content/output/review/decisions.json
#
# ────────────────────────────────────────────────────────────────
# Review dossier ready: /content/output/review
# Image shots processed:  24
#   with a chosen winner: 24
#   with no candidates:   0
# Winner source breakdown:
#   pexels           24
# Pinned portrait:        overrides/character.jpg
#   affects 5 portrait shot(s) at render time
#
# Next:
#   1. Open /content/output/review/ and review each shot folder.
#   2. Edit /content/output/review/decisions.json to swap candidates,
#      drop overrides into /content/output/review/overrides/,
#      or set 'pinned_portrait'.
#   3. Render:
#      python render_plan.py --plan output/al_askari_plan_v2.json \
#          --review-dir /content/output/review \
#          --audio <audio> --output <output.mp4>
# ────────────────────────────────────────────────────────────────

# %%
import os
import zipfile

output_dir = 'output/review'
zip_filename = 'review.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    files_added = []
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            file_path = os.path.join(root, file)
            # Add file to zip, preserving directory structure relative to 'output_dir'
            # Skip .mp3 files if any exist (though unlikely in review folder)
            if not file_path.endswith('.mp3'):
                zipf.write(file_path, os.path.relpath(file_path, output_dir))
                files_added.append(file_path)

print(f"🤐 Successfully created '{zip_filename}' containing: ")
if files_added:
    for f in files_added:
        print(f"  - {f}")
else:
    print("  (No files found to zip in the 'output/review' directory.)")
# Out:
# 🤐 Successfully created 'review.zip' containing:
#   - output/review/decisions.json
#   - output/review/README.txt
#   - output/review/shot_42_archive/pexels_a.jpg
#   - output/review/shot_42_archive/pexels_b.jpg
#   - output/review/shot_42_archive/context.txt
#   - output/review/shot_42_archive/pexels_c.jpg
#   - output/review/shot_42_archive/candidates.json
#   - output/review/shot_05_portrait/pexels_a.jpg
#   - output/review/shot_05_portrait/pexels_b.jpg
#   - output/review/shot_05_portrait/context.txt
#   - output/review/shot_05_portrait/pexels_c.jpg
#   - output/review/shot_05_portrait/candidates.json
#   - output/review/shot_14_broll/pexels_a.jpg
#   - output/review/shot_14_broll/pexels_b.jpg
#   - output/review/shot_14_broll/context.txt
#   - output/review/shot_14_broll/pexels_c.jpg
#   - output/review/shot_14_broll/candidates.json
#   - output/review/shot_13_archive/pexels_a.jpg
#   - output/review/shot_13_archive/pexels_b.jpg
#   - output/review/shot_13_archive/context.txt
#   - output/review/shot_13_archive/pexels_c.jpg
#   - output/review/shot_13_archive/candidates.json
#   - output/review/shot_31_archive/pexels_a.jpg
#   - output/review/shot_31_archive/pexels_b.jpg
#   - output/review/shot_31_archive/context.txt
#   - output/review/shot_31_archive/pexels_c.jpg
#   - output/review/shot_31_archive/candidates.json
#   - output/review/shot_34_archive/pexels_a.jpg
#   - output/review/shot_34_archive/pexels_b.jpg
#   - output/review/shot_34_archive/context.txt
#   - output/review/shot_34_archive/pexels_c.jpg
#   - output/review/shot_34_archive/candidates.json
#   - output/review/shot_26_portrait/pexels_a.jpg
#   - output/review/shot_26_portrait/pexels_b.jpg
#   - output/review/shot_26_portrait/context.txt
#   - output/review/shot_26_portrait/pexels_c.jpg
#   - output/review/shot_26_portrait/candidates.json
#   - output/review/shot_39_object/pexels_a.jpg
#   - output/review/shot_39_object/pexels_b.jpg
#   - output/review/shot_39_object/context.txt
#   - output/review/shot_39_object/pexels_c.jpg
#   - output/review/shot_39_object/candidates.json
#   - output/review/shot_16_portrait/pexels_a.jpg
#   - output/review/shot_16_portrait/pexels_b.jpg
#   - output/review/shot_16_portrait/context.txt
#   - output/review/shot_16_portrait/pexels_c.jpg
#   - output/review/shot_16_portrait/candidates.json
#   - output/review/shot_44_object/pexels_a.jpg
#   - output/review/shot_44_object/pexels_b.jpg
#   - output/review/shot_44_object/context.txt
#   - output/review/shot_44_object/pexels_c.jpg
#   - output/review/shot_44_object/candidates.json
#   - output/review/shot_11_location/pexels_a.jpg
#   - output/review/shot_11_location/pexels_b.jpg
#   - output/review/shot_11_location/context.txt
#   - output/review/shot_11_location/pexels_c.jpg
#   - output/review/shot_11_location/candidates.json
#   - output/review/shot_33_location/pexels_a.jpg
#   - output/review/shot_33_location/pexels_b.jpg
#   - output/review/shot_33_location/context.txt
#   - output/review/shot_33_location/pexels_c.jpg
#   - output/review/shot_33_location/candidates.json
#   - output/review/shot_36_portrait/pexels_a.jpg
#   - output/review/shot_36_portrait/pexels_b.jpg
#   - output/review/shot_36_portrait/context.txt
#   - output/review/shot_36_portrait/pexels_c.jpg
#   - output/review/shot_36_portrait/candidates.json
#   - output/review/shot_24_archive/pexels_a.jpg
#   - output/review/shot_24_archive/pexels_b.jpg
#   - output/review/shot_24_archive/context.txt
#   - output/review/shot_24_archive/pexels_c.jpg
#   - output/review/shot_24_archive/candidates.json
#   - output/review/overrides/character.jpg
#   - output/review/shot_22_archive/pexels_a.jpg
#   - output/review/shot_22_archive/pexels_b.jpg
#   - output/review/shot_22_archive/context.txt
#   - output/review/shot_22_archive/pexels_c.jpg
#   - output/review/shot_22_archive/candidates.json
#   - output/review/shot_08_location/pexels_a.jpg
#   - output/review/shot_08_location/pexels_b.jpg
#   - output/review/shot_08_location/context.txt
#   - output/review/shot_08_location/pexels_c.jpg
#   - output/review/shot_08_location/candidates.json
#   - output/review/shot_41_portrait/pexels_a.jpg
#   - output/review/shot_41_portrait/pexels_b.jpg
#   - output/review/shot_41_portrait/context.txt
#   - output/review/shot_41_portrait/pexels_c.jpg
#   - output/review/shot_41_portrait/candidates.json
#   - output/review/shot_10_location/pexels_a.jpg
#   - output/review/shot_10_location/pexels_b.jpg
#   - output/review/shot_10_location/context.txt
#   - output/review/shot_10_location/pexels_c.jpg
#   - output/review/shot_10_location/candidates.json
#   - output/review/shot_03_archive/pexels_a.jpg
#   - output/review/shot_03_archive/pexels_b.jpg
#   - output/review/shot_03_archive/context.txt
#   - output/review/shot_03_archive/pexels_c.jpg
#   - output/review/shot_03_archive/candidates.json
#   - output/review/shot_17_archive/pexels_a.jpg
#   - output/review/shot_17_archive/pexels_b.jpg
#   - output/review/shot_17_archive/context.txt
#   - output/review/shot_17_archive/pexels_c.jpg
#   - output/review/shot_17_archive/candidates.json
#   - output/review/shot_06_archive/pexels_a.jpg
#   - output/review/shot_06_archive/pexels_b.jpg
#   - output/review/shot_06_archive/context.txt
#   - output/review/shot_06_archive/pexels_c.jpg
#   - output/review/shot_06_archive/candidates.json
#   - output/review/shot_28_broll/pexels_a.jpg
#   - output/review/shot_28_broll/pexels_b.jpg
#   - output/review/shot_28_broll/context.txt
#   - output/review/shot_28_broll/pexels_c.jpg
#   - output/review/shot_28_broll/candidates.json
#   - output/review/shot_21_location/pexels_a.jpg
#   - output/review/shot_21_location/pexels_b.jpg
#   - output/review/shot_21_location/context.txt
#   - output/review/shot_21_location/pexels_c.jpg
#   - output/review/shot_21_location/candidates.json
#   - output/review/shot_19_broll/pexels_a.jpg
#   - output/review/shot_19_broll/pexels_b.jpg
#   - output/review/shot_19_broll/context.txt
#   - output/review/shot_19_broll/pexels_c.jpg
#   - output/review/shot_19_broll/candidates.json

# %%
# Step 3: user reviews output/review/ — opens decisions.json, swaps a
# few `chosen_url` values, drops shot_03.jpg / shot_38.jpg overrides.

# Step 4: render — render_plan.py reads the decisions file
# The --review-dir argument consumes user's choices
# !python render_plan.py \
    --plan         output/al_askari_plan_v2.json \
    --audio        output/al_askari_audio.mp3 \
    --review-dir   output/review/ \
    --output       output/final_cut.mp4 \
    > output/render.log 2>&1 &

# %%
# Monitor rendering progress
import time
from IPython.display import clear_output

log_path = "output/render.log"

print("Monitoring rendering progress...")
while True:
    try:
        # Read the log file contents
        try:
            with open(log_path, "r") as f:
                log_content = f.read()
        except FileNotFoundError:
            log_content = ""

        # Clear cell output and show the last 20 lines
        clear_output(wait=True)
        lines = log_content.splitlines()
        print("\n".join(lines[-20:]))

        # Check if the script's success signature is in the log
        if "Done in" in log_content or "Rendered video →" in log_content:
            print("\n✅ Rendering process completed successfully! Stopped monitoring.")
            break

        time.sleep(5)

    except KeyboardInterrupt:
        print("\n⚠️ Monitoring stopped manually. The script may still be running.")
        break
# Out:
#   [████████████████████░░░░░░░░░░]  69%  shot 44/48: object                                                    INFO  phase3.render  [render 71%] shot 45/48: typography
#
#   [█████████████████████░░░░░░░░░]  70%  shot 45/48: typography                                                INFO  phase3.render  [render 72%] shot 46/48: typography
#
#   [█████████████████████░░░░░░░░░]  72%  shot 46/48: typography                                                INFO  phase3.render  [render 74%] shot 47/48: typography
#
#   [██████████████████████░░░░░░░░]  73%  shot 47/48: typography                                                INFO  phase3.render  [render 75%] shot 48/48: title_card
#
#   [██████████████████████░░░░░░░░]  74%  shot 48/48: title_card                                                INFO  phase3.render  [render 80%] concat all shots
#
#   [████████████████████████░░░░░░]  80%  concat all shots                                                      INFO  phase3.render  [render 86%] generating captions
#
#   [█████████████████████████░░░░░]  86%  generating captions                                                   INFO  phase3.render  [render 92%] mux audio and captions
#
#   [███████████████████████████░░░]  92%  mux audio and captions                                                INFO  phase3.render  [render 100%] done
#
#   [██████████████████████████████] 100%  done
# INFO  phase3.render  Rendered video → output/final_cut.mp4
#
# Done in 629s  —  output/final_cut.mp4  (25.5 MB)
#
# ✅ Rendering process completed successfully! Stopped monitoring.

# %%
# Zip output files for exporting
import os
import zipfile

output_dir = 'output'
zip_filename = 'output_files.zip'

# Get all files in the output directory
files_to_zip = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if os.path.isfile(os.path.join(output_dir, f))]

# Filter out the .mp3 file
filtered_files = [f for f in files_to_zip if not f.endswith('.mp3')]

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file_path in filtered_files:
        # Add file to zip, preserving directory structure relative to 'output_dir'
        zipf.write(file_path, os.path.relpath(file_path, output_dir))

print(f"🤐 Successfully created '{zip_filename}' containing: ")
for f in filtered_files:
    print(f"  - {f}")
# Out:
# 🤐 Successfully created 'output_files.zip' containing:
#   - output/final_cut.mp4
#   - output/word_timings.json
#   - output/render.log
#   - output/al_askari_plan_v2.json
#   - output/planner_raw_response.txt

# %%
# Save zipped file to Drive
from google.colab import drive
drive.mount('/content/drive')

import shutil
import os

# Define the destination directory and file path
dest_dir = '/content/drive/MyDrive/_Phase3'
dest_file_path = os.path.join(dest_dir, 'output_files.zip')

# Create the destination directory if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)
print(f"Destination directory '{dest_dir}' ensured to exist.")

# --- Test write access to the directory ---
test_file = os.path.join(dest_dir, 'test_write.txt')
try:
    with open(test_file, 'w') as f:
        f.write('This is a test file.\n')
    print(f"✅ Successfully wrote test file to '{test_file}'.")
    os.remove(test_file) # Clean up the test file
    print(f"Test file '{test_file}' removed.")
except Exception as e:
    print(f"Error writing test file to '{test_file}': {e}")
    print("⚠️ It seems there might be a permissions or access issue with Google Drive.")
    # Exit or raise an error if write access fails
    raise
# ----------------------------------------

shutil.copy('/content/output_files.zip', dest_file_path)
print(f"📽️ rough_cut.mp4 saved to Google Drive at '{dest_file_path}'.")
# Out:
# Mounted at /content/drive
# Destination directory '/content/drive/MyDrive/_Phase3' ensured to exist.
# ✅ Successfully wrote test file to '/content/drive/MyDrive/_Phase3/test_write.txt'.
# Test file '/content/drive/MyDrive/_Phase3/test_write.txt' removed.
# 📽️ rough_cut.mp4 saved to Google Drive at '/content/drive/MyDrive/_Phase3/output_files.zip'.
